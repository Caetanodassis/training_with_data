# %% [markdown]
# # Análise de Ausências Empregados
#
# ## Objetivo
#
# Calcular para cada mês do intervalo informado, quantos dias cada empregado esteve ausente e qual a representatividade destas ausências em absenteismo
# (soma_ausencias / dias_uteis)
#
# ## Dados
#
# Os dados foram capturados do por IA, anotando cada dia ausente para cada empregado da unidade. Foram consideradas ausencias as Licencias Medicas
#
# ## Entregas
#
# - Absenteismo Geral
# - Absenteismo por Fucionario
# - Absenteismo por Mês
# - Absenteismo por Dias da semana
# - Absenteismo por Missão
#
# ## Obs:
# Essa demanda foi feita no meu estágio na Caixa Economica Federal, não posso usar os dados reais para essa demanda, sendo assim, pedi para IA criar uma base de dados semlhantes

# %% [markdown]
# ## Importando Biblioteca ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import textwrap
import matplotlib.patheffects as pe

from datetime import date, timedelta
from pandas.tseries.offsets import CustomBusinessDay
from matplotlib.ticker import FuncFormatter

# %% [markdown]
# ## Dados
#
# Nesta etapa, mostra como importei os dados e tratei

# %% [markdown]
# ### Carregando os tabela

# %%
df = pd.read_csv('dataset/BASE_DEPARTAMENTOS_MAIS_AUSENCIAS.csv', sep = ';', encoding="cp1252")

# %% [markdown]
# ### Vizualizando a tabela

# %%
df.head()
# Out:
#                             NOMES       DATAS                      MISSAO
# 0      ANA GOMES PINTO DOS SANTOS         NaN                  Facilities
# 1       ANA LIMA DANTAS DE VIEIRA  28/10/2025  Planejamento e EstratÃ©gia
# 2       ANA LIMA DANTAS DE VIEIRA  18/12/2025  Planejamento e EstratÃ©gia
# 3    ANA RIBEIRO PINTO DE RIBEIRO         NaN               Controladoria
# 4  ANA TEIXEIRA PINTO DE FERREIRA         NaN      Atendimento ao Cliente

# %% [markdown]
# ### Verificando o tipo do dados e sua quantidade de linhas, se há nullos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOMES   237 non-null    object
#  1   DATAS   138 non-null    object
#  2   MISSAO  237 non-null    object
# dtypes: object(3)
# memory usage: 5.7+ KB

# %% [markdown]
# ### Arrumando o tipo de data e também adicionando uma coluna com os dias da semana

# %%
# transformando a coluna em tipo data / transformando em null os dados vazios

df_data_corrigido = df.copy()

df_data_corrigido['DATAS'] = df_data_corrigido['DATAS'].astype('string').str.strip().replace('', pd.NA)

# transformando em tipo data
df_data_corrigido.loc[:,'DATAS'] = pd.to_datetime(df_data_corrigido.loc[:,'DATAS'], dayfirst = True, errors = 'coerce')

# removendo as horas da variável
df_data_corrigido.loc[:,'DATAS'] = df_data_corrigido.loc[:,'DATAS'].dt.date

df_add_dias = df_data_corrigido.copy()

# acrescentando dias da semana atraves das datas
mapa_pt = {
    "Monday": "Segunda-feira",
    "Tuesday": "Terça-feira",
    "Wednesday": "Quarta-feira",
    "Thursday": "Quinta-feira",
    "Friday": "Sexta-feira",
    "Saturday": "Sábado",
    "Sunday": "Domingo",
}
df_add_dias["DIA_SEMANA"] = df_add_dias["DATAS"].dt.day_name().map(mapa_pt)

df_add_dias = df_data_corrigido.copy()

# acrescentando dias da semana atraves das datas
mapa_pt = {
    "Monday": "Segunda-feira",
    "Tuesday": "Terça-feira",
    "Wednesday": "Quarta-feira",
    "Thursday": "Quinta-feira",
    "Friday": "Sexta-feira",
    "Saturday": "Sábado",
    "Sunday": "Domingo",
}
df_add_dias["DIA_SEMANA"] = df_add_dias["DATAS"].dt.day_name().map(mapa_pt)

df_add_dias.head()
# Out:
#                             NOMES      DATAS                      MISSAO  \
# 0      ANA GOMES PINTO DOS SANTOS        NaT                  Facilities
# 1       ANA LIMA DANTAS DE VIEIRA 2025-10-28  Planejamento e EstratÃ©gia
# 2       ANA LIMA DANTAS DE VIEIRA 2025-12-18  Planejamento e EstratÃ©gia
# 3    ANA RIBEIRO PINTO DE RIBEIRO        NaT               Controladoria
# 4  ANA TEIXEIRA PINTO DE FERREIRA        NaT      Atendimento ao Cliente
#
#      DIA_SEMANA
# 0           NaN
# 1   Terça-feira
# 2  Quinta-feira
# 3           NaN
# 4           NaN

# %% [markdown]
# ## Padrões
#
# Nesse topico algumas variaveis foram definidas para como periodo de 01 de Agosto de 2025 a dia 30 de janeiro de 2026 (apliquei uma função que contava somente os dias uteis desse periodo, que são 128 dias ) e a quantidade de Fucionários, que são 141 fucionarios

# %% [markdown]
# ### Parâmetros do período (automático)
#
# O que faz: define inicio_dt e fim_dt automaticamente a partir da menor e maior data da sua coluna DATAS.
# Por que: evita hardcode e garante que o resto do pipeline sempre use o período correto.

# %%
# Garante tipo datetime (dd/mm/aaaa)
df_add_dias["DATAS"] = pd.to_datetime(df_add_dias["DATAS"], dayfirst=True, errors="coerce")
if df_add_dias["DATAS"].isna().all():
    raise ValueError("Nenhuma data válida encontrada em df_add_dias['DATAS'].")

acolchoar_dias = 0  # ajuste se quiser expandir o intervalo (ex.: 3 dias a mais nas pontas)
inicio_dt = df_add_dias["DATAS"].min().normalize() - pd.Timedelta(days=acolchoar_dias)
fim_dt    = df_add_dias["DATAS"].max().normalize() + pd.Timedelta(days=acolchoar_dias)

print("Período:", inicio_dt.date(), "→", fim_dt.date())
# Out:
# Período: 2025-08-01 → 2026-01-30

# %% [markdown]
# ### Datas móveis (Páscoa, Carnaval etc.)
# O que faz: Implementa funções para calcular feriados móveis (Páscoa, Paixão, Corpus Christi, Carnaval).
# Por que: Esses feriados mudam todo ano e são necessários para um calendário correto.

# %%
# datas móveis

def easter_date(y: int) -> date:
    """Páscoa (algoritmo Meeus/Jones/Butcher)"""
    a = y % 19
    b = y // 100
    c = y % 100
    d = b // 4
    e = b % 4
    f = (b + 8) // 25
    g = (b - f + 1) // 3
    h = (19*a + b - d - g + 15) % 30
    i = c // 4
    k = c % 4
    l = (32 + 2*e + 2*i - h - k) % 7
    m = (a + 11*h + 22*l) // 451
    month = (h + l - 7*m + 114) // 31
    day   = ((h + l - 7*m + 114) % 31) + 1
    return date(y, month, day)

def carnaval_dates(y: int):
    """Carnaval (segunda e terça) e Cinzas (quarta até 14h)"""
    pascoa = easter_date(y)
    return (
        pascoa - timedelta(days=48),  # segunda
        pascoa - timedelta(days=47),  # terça
        pascoa - timedelta(days=46),  # cinzas
    )

def paixao_de_cristo(y: int):
    return easter_date(y) - timedelta(days=2)  # sexta-feira santa

def corpus_christi(y: int):
    return easter_date(y) + timedelta(days=60)

# %% [markdown]
# ### Feriados nacionais + locais (DF) por ano
#
# O que faz: monta a tabela de feriados (fixos + móveis) e pontos facultativos (separados).
# Por que: você pode escolher incluir/ excluir pontos facultativos do cálculo.

# %%
# feriados por ano (Nacionais + DF)
def feriados_br_df(ano: int, incluir_pontos_facultativos: bool = False):
    # Feriados nacionais fixos
    feriados = {
        date(ano, 1,  1): "Confraternização Universal (Nacional)",
        date(ano, 4, 21): "Tiradentes (Nacional) + Aniversário de Brasília (DF)",
        date(ano, 5,  1): "Dia do Trabalho (Nacional)",
        date(ano, 9,  7): "Independência do Brasil (Nacional)",
        date(ano,10, 12): "Nossa Senhora Aparecida (Nacional)",
        date(ano,11,  2): "Finados (Nacional)",
        date(ano,11, 15): "Proclamação da República (Nacional)",
        date(ano,11, 20): "Dia da Consciência Negra (Nacional)",
        date(ano,12, 25): "Natal (Nacional)",
    }
    # móveis (nacionais)
    feriados[paixao_de_cristo(ano)] = "Paixão de Cristo / Sexta-feira Santa (Nacional)"
    # Locais (DF)
    feriados[date(ano,11,30)] = "Dia do Evangélico (DF - Lei nº 963/1995)"
    feriados[corpus_christi(ano)] = "Corpus Christi (DF - feriado/ponto local)"

    # pontos facultativos (separados)
    pontos = {}
    seg, ter, qua = carnaval_dates(ano)
    pontos[seg] = "Carnaval (ponto facultativo)"
    pontos[ter] = "Carnaval (ponto facultativo)"
    pontos[qua] = "Quarta-feira de Cinzas até 14h (ponto facultativo)"
    pontos[date(ano,12,24)] = "Véspera de Natal (ponto facultativo após 14h)"
    pontos[date(ano,12,31)] = "Véspera de Ano-Novo (ponto facultativo após 14h)"

    if incluir_pontos_facultativos:
        feriados = {**feriados, **pontos}

    return feriados, pontos

# %% [markdown]
# ### Feriados do intervalo (todos os anos) e DataFrame final
#
# O que faz: gera a lista completa de feriados (e pontos) para todos os anos entre inicio_dt e fim_dt, e prepara o feriados_df.
# Por que: evita limitar a um ano; funciona para períodos cruzando anos.

# %%
# feriados do intervalo
anos = range(inicio_dt.year, fim_dt.year + 1)
feriados_dict = {}
pontos_dict   = {}

for ano in anos:
    f, p = feriados_br_df(ano, incluir_pontos_facultativos=False)
    feriados_dict.update(f)
    pontos_dict.update(p)

feriados_df = (
    pd.DataFrame(
        [{"DATA": pd.to_datetime(d), "NOME": n, "TIPO": "FERIADO"} for d, n in feriados_dict.items()]
        +
        [{"DATA": pd.to_datetime(d), "NOME": n, "TIPO": "PONTO FACULTATIVO"} for d, n in pontos_dict.items()]
    )
    .sort_values("DATA")
    .reset_index(drop=True)
)

# se quiser considerar pontos facultativos como feriado nos cálculos, mude para .isin(["FERIADO","PONTO FACULTATIVO"])
feriados_idx = pd.DatetimeIndex(
    feriados_df.loc[feriados_df["TIPO"] == "FERIADO", "DATA"].dt.normalize().unique()
)

# feriados dentro do período
feriados_periodo = feriados_df[(feriados_df["DATA"] >= inicio_dt) & (feriados_df["DATA"] <= fim_dt)].copy()

# %% [markdown]
# ### Marcação de feriados no seu DataFrame
#
# O que faz: filtra o seu DF para o período e marca colunas indicando se cada data é feriado e o nome do feriado.
# Por que: útil para flag de ausência em feriado, validações e auditorias.

# %%
# marcação de feriados no seu DataFrame
df_periodo = df_add_dias[(df_add_dias["DATAS"] >= inicio_dt) & (df_add_dias["DATAS"] <= fim_dt)].copy()
df_periodo["_DATA"] = df_periodo["DATAS"].dt.normalize()

# conjuntos normalizados
feriados_datas = set(feriados_df.loc[feriados_df["TIPO"] == "FERIADO", "DATA"].dt.normalize())
pontos_datas   = set(feriados_df.loc[feriados_df["TIPO"] == "PONTO FACULTATIVO", "DATA"].dt.normalize())

# mapas
mapa_nome_feriado = {pd.to_datetime(d).normalize(): n for d, n in feriados_dict.items()}
mapa_nome_ponto   = {pd.to_datetime(d).normalize(): n for d, n in pontos_dict.items()}

# flags e nomes
df_periodo["E_FERIADO"]    = df_periodo["_DATA"].isin(feriados_datas)
df_periodo["NOME_FERIADO"] = df_periodo["_DATA"].map(mapa_nome_feriado)

df_periodo["E_PONTO_FACULTATIVO"]    = df_periodo["_DATA"].isin(pontos_datas)
df_periodo["NOME_PONTO_FACULTATIVO"] = df_periodo["_DATA"].map(mapa_nome_ponto)

df_periodo.drop(columns=["_DATA"], inplace=True)

df_periodo.head()
# Out:
#                                NOMES      DATAS                      MISSAO  \
# 1          ANA LIMA DANTAS DE VIEIRA 2025-10-28  Planejamento e EstratÃ©gia
# 2          ANA LIMA DANTAS DE VIEIRA 2025-12-18  Planejamento e EstratÃ©gia
# 7    BRUNO NOGUEIRA MARTINS DE SOUZA 2025-10-23       Compras e Suprimentos
# 8    BRUNO NOGUEIRA MARTINS DE SOUZA 2025-11-20       Compras e Suprimentos
# 9  BRUNO SANTOS BARBOSA DE RODRIGUES 2025-09-19         Engenharia de Dados
#
#      DIA_SEMANA  E_FERIADO                         NOME_FERIADO  \
# 1   Terça-feira      False                                  NaN
# 2  Quinta-feira      False                                  NaN
# 7  Quinta-feira      False                                  NaN
# 8  Quinta-feira       True  Dia da Consciência Negra (Nacional)
# 9   Sexta-feira      False                                  NaN
#
#    E_PONTO_FACULTATIVO NOME_PONTO_FACULTATIVO
# 1                False                    NaN
# 2                False                    NaN
# 7                False                    NaN
# 8                False                    NaN
# 9                False                    NaN

# %% [markdown]
# ### Dias úteis do período (com e sem feriado)
#
# O que faz: calcula total de dias úteis do período, e remove feriados.
# Por que: esses números entram nos denominadores de várias métricas (se você desejar).

# %%
# dias úteis do período
from pandas.tseries.offsets import CustomBusinessDay

# dias úteis padrão (segunda a sexta)
dias_uteis = pd.bdate_range(start=inicio_dt, end=fim_dt)

# excluir somente feriados:
feriados_para_excluir = pd.to_datetime(sorted(list(feriados_datas)))

dias_sem_feriado = dias_uteis.difference(pd.DatetimeIndex(feriados_para_excluir))
dias_previstos = len(dias_sem_feriado)

print("Dias úteis (seg-sex):", len(dias_uteis))
print("Dias úteis sem feriados:", dias_previstos)
# Out:
# Dias úteis (seg-sex): 131
# Dias úteis sem feriados: 128

# %% [markdown]
# ### Diagnóstico

# %%
total_funcionarios = df_add_dias['NOMES'].nunique()

print("Total de funcionários:", total_funcionarios)
print("Período:", inicio_dt.date(), "a", fim_dt.date())

print("\nFeriados no período:")
print(
    feriados_periodo[feriados_periodo["TIPO"] == "FERIADO"][["DATA","NOME"]]
    .to_string(index=False)
)

feriados_uteis = pd.DatetimeIndex(sorted(feriados_datas)).intersection(pd.bdate_range(inicio_dt, fim_dt))
print("\nFeriados que caem em dias úteis no período:")
for d in feriados_uteis:
    print(d.date(), "-", mapa_nome_feriado.get(pd.to_datetime(d).normalize()))
# Out:
# Total de funcionários: 141
# Período: 2025-08-01 a 2026-01-30
#
# Feriados no período:
#       DATA                                     NOME
# 2025-09-07       Independência do Brasil (Nacional)
# 2025-10-12       Nossa Senhora Aparecida (Nacional)
# 2025-11-02                       Finados (Nacional)
# 2025-11-15      Proclamação da República (Nacional)
# 2025-11-20      Dia da Consciência Negra (Nacional)
# 2025-11-30 Dia do Evangélico (DF - Lei nº 963/1995)
# 2025-12-25                         Natal (Nacional)
# 2026-01-01    Confraternização Universal (Nacional)
#
# Feriados que caem em dias úteis no período:
# 2025-11-20 - Dia da Consciência Negra (Nacional)
# 2025-12-25 - Natal (Nacional)
# 2026-01-01 - Confraternização Universal (Nacional)

# %% [markdown]
# ## Absenteismo Geral
#
# Nesta etapa, analisamos o absenteismo geral e também por fucionario

# %% [markdown]
# ### Calculando os dias ausentes por fucionario (dias distintos)

# %%
# importando dados do df original
df_dados_geral = df_add_dias.copy()

# %%
# Quantos dias ausentes por funcionario (dias distintos)
dias_ausentes_por_pessoa = df_periodo.groupby("NOMES")["DATAS"].nunique()

# %% [markdown]
# ### Calculando o absenteismo por Fucionario
#
# Calculo = dias_ausentes_por_fucionario/dias_previstos

# %%
# resultado final do Absenteismo dos fucionarios
resultado_dados_geral = dias_ausentes_por_pessoa.to_frame(name="DIAS_AUSENTES")
resultado_dados_geral["DIAS_PREVISTOS"] = dias_previstos

resultado_dados_geral['ABSENTEISMO_%'] = (
    (resultado_dados_geral['DIAS_AUSENTES'] / resultado_dados_geral['DIAS_PREVISTOS']) * 100
).round(2)

# ordenar do maior para o menor
resultado_dados_geral = resultado_dados_geral.sort_values("ABSENTEISMO_%", ascending=False)

# %% [markdown]
# ### Calculando o Absenteismo Geral
# Calculo = dias_ausentes_por_fucionario/dias_previstos * Quantidade_de_fucionario

# %%
# total previsto de "dias-pessoa" = 71 pessoas * dias úteis do período
denominador_geral = total_funcionarios * dias_previstos

# total de dias ausentes (somando todo mundo que apareceu no df_periodo)
total_dias_ausentes = dias_ausentes_por_pessoa.sum()

# indice geral (%)
absenteismo_geral = (
    round((total_dias_ausentes / denominador_geral) * 100, 2)
    if denominador_geral > 0
    else np.nan
)

# qtd de funcionarios com registro no período
funcionarios_com_registro_no_periodo = df_periodo["NOMES"].nunique()
total_dias_ausentes
# Out:
# 138

# %% [markdown]
# ### Calculo Mediana e Media do absenteismo por fucionario

# %%
# media do absenteísmo (%)
media_absenteismo = resultado_dados_geral["ABSENTEISMO_%"].mean()

# mediana do absenteísmo (%)
mediana_absenteismo = resultado_dados_geral["ABSENTEISMO_%"].median()

# %% [markdown]
# ### Resumo das Medidas

# %%
# vizualisação dos resultados
display(resultado_dados_geral)

print(f"Dias previstos no período (por funcionário): {dias_previstos}")
print(f"Funcionários com registro no período: {funcionarios_com_registro_no_periodo}")
print(f"Total de funcionários considerados: {total_funcionarios}")
print(f"Absenteísmo geral (todos os fucionarios) (%): {absenteismo_geral}")
# Out:
#                                      DIAS_AUSENTES  DIAS_PREVISTOS  \
# NOMES
# WAGNER SOUZA SANTANA DA COSTA                    5             128
# VICTOR DANTAS ALVES DE MOURA                     5             128
# JULIA AMARAL ROCHA DE RODRIGUES                  5             128
# DANIEL VIEIRA ALMEIDA DE SANTANA                 5             128
# FERNANDA BRAGA DANTAS DE ARAUJO                  5             128
# RAFAELLA GOMES SANTANA DO CARMO                  5             128
# ELISA MORAES LOPES DE ROCHA                      5             128
# ENZO VIEIRA BEZERRA DE RIBEIRO                   5             128
# THIAGO DIAS MORAES DE VIEIRA                     4             128
# RENATO SOUZA SILVA DE FERREIRA                   4             128
# HENRIQUE PEREIRA ALMEIDA DE LIMA                 4             128
# JOAO BARBOSA TEIXEIRA DE SANTANA                 4             128
# ELISA SILVA RODRIGUES DA CUNHA                   4             128
# ENZO AMARAL PINTO DE SANTOS                      4             128
# EMANUELA CUNHA PINTO DE TEIXEIRA                 4             128
# HEITOR LOPES ALMEIDA DE FERREIRA                 4             128
# DIEGO SANTOS VIEIRA DE VIEIRA                    4             128
# DAVI SOARES BARBOSA DE VIEIRA                    4             128
# RAFAEL RODRIGUES ALMEIDA DA SILVA                4             128
# CAMILA GOMES BATISTA DE RIBEIRO                  4             128
# HELIO BEZERRA NOGUEIRA DE BARBOSA                3             128
# ENZO VIEIRA CARDOSO DE RIBEIRO                   3             128
# FERNANDA MORAES MENDES DE SANTANA                3             128
# DANIEL BEZERRA TEIXEIRA DE TEIXEIRA              3             128
# CAMILA SOARES PEREIRA DE BARBOSA                 3             128
# MARCELA PINTO CARVALHO DE SANTANA                3             128
# RAFAELLA MOURA ALMEIDA DE RODRIGUES              2             128
# RAFAELLA ROCHA LOPES DE BARBOSA                  2             128
# SABRINA BRAGA COSTA DE BARBOSA                   2             128
# LETICIA RODRIGUES AMARAL DE LIMA                 2             128
# ANA LIMA DANTAS DE VIEIRA                        2             128
# LETICIA OLIVEIRA AMARAL DE SOUZA                 2             128
# KARINA BARROS AMARAL DE MOURA                    2             128
# JOSE DANTAS ROCHA DA COSTA                       2             128
# ISABELA SOUZA DIAS DE RIBEIRO                    2             128
# BRUNO NOGUEIRA MARTINS DE SOUZA                  2             128
# HEITOR CAMPOS BARBOSA DE SANTOS                  2             128
# GABRIEL BEZERRA SOUZA DE TEIXEIRA                2             128
# FELIPE COSTA MORAES DE RIBEIRO                   2             128
# ENZO MOURA RODRIGUES DE ARAUJO                   2             128
# BRUNO SANTOS BARBOSA DE RODRIGUES                2             128
# HEITOR DANTAS ALVES DE RODRIGUES                 2             128
#
#                                      ABSENTEISMO_%
# NOMES
# WAGNER SOUZA SANTANA DA COSTA                 3.91
# VICTOR DANTAS ALVES DE MOURA                  3.91
# JULIA AMARAL ROCHA DE RODRIGUES               3.91
# DANIEL VIEIRA ALMEIDA DE SANTANA              3.91
# FERNANDA BRAGA DANTAS DE ARAUJO               3.91
# RAFAELLA GOMES SANTANA DO CARMO               3.91
# ELISA MORAES LOPES DE ROCHA                   3.91
# ENZO VIEIRA BEZERRA DE RIBEIRO                3.91
# THIAGO DIAS MORAES DE VIEIRA                  3.12
# RENATO SOUZA SILVA DE FERREIRA                3.12
# HENRIQUE PEREIRA ALMEIDA DE LIMA              3.12
# JOAO BARBOSA TEIXEIRA DE SANTANA              3.12
# ELISA SILVA RODRIGUES DA CUNHA                3.12
# ENZO AMARAL PINTO DE SANTOS                   3.12
# EMANUELA CUNHA PINTO DE TEIXEIRA              3.12
# HEITOR LOPES ALMEIDA DE FERREIRA              3.12
# DIEGO SANTOS VIEIRA DE VIEIRA                 3.12
# DAVI SOARES BARBOSA DE VIEIRA                 3.12
# RAFAEL RODRIGUES ALMEIDA DA SILVA             3.12
# CAMILA GOMES BATISTA DE RIBEIRO               3.12
# HELIO BEZERRA NOGUEIRA DE BARBOSA             2.34
# ENZO VIEIRA CARDOSO DE RIBEIRO                2.34
# FERNANDA MORAES MENDES DE SANTANA             2.34
# DANIEL BEZERRA TEIXEIRA DE TEIXEIRA           2.34
# CAMILA SOARES PEREIRA DE BARBOSA              2.34
# MARCELA PINTO CARVALHO DE SANTANA             2.34
# RAFAELLA MOURA ALMEIDA DE RODRIGUES           1.56
# RAFAELLA ROCHA LOPES DE BARBOSA               1.56
# SABRINA BRAGA COSTA DE BARBOSA                1.56
# LETICIA RODRIGUES AMARAL DE LIMA              1.56
# ANA LIMA DANTAS DE VIEIRA                     1.56
# LETICIA OLIVEIRA AMARAL DE SOUZA              1.56
# KARINA BARROS AMARAL DE MOURA                 1.56
# JOSE DANTAS ROCHA DA COSTA                    1.56
# ISABELA SOUZA DIAS DE RIBEIRO                 1.56
# BRUNO NOGUEIRA MARTINS DE SOUZA               1.56
# HEITOR CAMPOS BARBOSA DE SANTOS               1.56
# GABRIEL BEZERRA SOUZA DE TEIXEIRA             1.56
# FELIPE COSTA MORAES DE RIBEIRO                1.56
# ENZO MOURA RODRIGUES DE ARAUJO                1.56
# BRUNO SANTOS BARBOSA DE RODRIGUES             1.56
# HEITOR DANTAS ALVES DE RODRIGUES              1.56
# Dias previstos no período (por funcionário): 128
# Funcionários com registro no período: 42
# Total de funcionários considerados: 141
# Absenteísmo geral (todos os fucionarios) (%): 0.76

# %% [markdown]
# ## Absenteismo por Mes
#
# Nesta etapa, organizamos os dados montando uma tabela que traz para cada empregado a quantidade de ausencias efetivas em um determinado mês, o absenteismo do mes, e dias uteis de cada mes

# %% [markdown]
# ### Definido o Perido mensal (Dias Uteis em Cada Mes)

# %%
considerar_ponto_facultativo_como_feriado = False

if considerar_ponto_facultativo_como_feriado:
    feriados_idx = pd.DatetimeIndex(
        feriados_df.loc[feriados_df["TIPO"].isin(["FERIADO","PONTO FACULTATIVO"]), "DATA"]
        .dt.normalize()
        .unique()
    )
else:
    feriados_idx = pd.DatetimeIndex(
        feriados_df.loc[feriados_df["TIPO"]=="FERIADO", "DATA"]
        .dt.normalize()
        .unique()
    )

dias_previstos_por_mes = (
    pd.DataFrame({"DATA": dias_sem_feriado})
      .assign(
          MES=lambda x: x["DATA"].dt.to_period("M"),
          MES_LABEL=lambda x: x["DATA"].dt.strftime("%b/%Y").str.capitalize()
      )
      .groupby(["MES","MES_LABEL"], as_index=False)
      .size()
      .rename(columns={"size":"DIAS_PREVISTOS"})
)

# %% [markdown]
# ### Criando uma Tabela Para Dias Ausentes por Funcionario e por Mes

# %%
df_periodo = df_add_dias[(df_add_dias["DATAS"]>=inicio_dt) & (df_add_dias["DATAS"]<=fim_dt)].copy()
df_periodo["MES"] = df_periodo["DATAS"].dt.to_period("M")
df_periodo["MES_LABEL"] = df_periodo["DATAS"].dt.strftime("%b/%Y").str.capitalize()

ausencias_mensais = (
    df_periodo.groupby(["NOMES","MES","MES_LABEL"])
              .size()
              .reset_index(name="DIAS_AUSENTES")
)

# %% [markdown]
# ### Criando a Tabela Lista de Fucionario

# %%
lista_funcionarios = (
    df_add_dias["NOMES"].dropna().astype(str).unique().tolist()
)
meses_periodo = dias_previstos_por_mes["MES"].unique().tolist()

# %% [markdown]
# ### Juntando as Tabelas Criandas Anteriomente
#
# Nesta etapa, organizamos os dados montando uma tabela que traz para cada empregado a quantidade de ausencias efetivas em um determinado mês. Se o funcionário não faltou no mes, uma entrada na tabela será registrada com o valor zero.

# %%
grade = pd.MultiIndex.from_product(
    [lista_funcionarios, meses_periodo],
    names=["NOMES","MES"]
).to_frame(index=False)

# %% [markdown]
# ### Calcula o Absenteismo em Cada Mes (Geral Por Mes)
#
# calculo = dias de ausencia / perido * numeros de fucionario

# %%
tabela_mensal = (
    grade
    # junta ausências
    .merge(ausencias_mensais[["NOMES","MES","DIAS_AUSENTES"]],
           on=["NOMES","MES"], how="left")
    # junta dias previstos
    .merge(dias_previstos_por_mes[["MES","MES_LABEL","DIAS_PREVISTOS"]],
           on="MES", how="left")
)

tabela_mensal["DIAS_AUSENTES"] = pd.to_numeric(tabela_mensal["DIAS_AUSENTES"], errors="coerce").fillna(0).astype(int)

tabela_mensal["ABSENTEISMO_MES_%"] = np.where(
    tabela_mensal["DIAS_PREVISTOS"].fillna(0) > 0,
    (tabela_mensal["DIAS_AUSENTES"] / tabela_mensal["DIAS_PREVISTOS"]) * 100,
    np.nan
).round(2)

tabela_mensal = tabela_mensal.sort_values(["NOMES","MES"]).reset_index(drop=True)

# %% [markdown]
# ### Preparando os Dados Para Realiza o Calculo absenteismo do Mes Geral

# %%
tmp = tabela_mensal.copy()
tmp.loc[:, "DIAS_AUSENTES"] = pd.to_numeric(tmp.loc[:, "DIAS_AUSENTES"], errors="coerce").fillna(0)

dpm = dias_previstos_por_mes.copy()

# se a coluna existir e não for PeriodDtype, converte para PeriodIndex mensal
if "MES" in dpm.columns and not isinstance(dpm["MES"].dtype, pd.PeriodDtype):
    dpm.loc[:, "MES"] = pd.PeriodIndex(dpm.loc[:, "MES"], freq="M")

# %% [markdown]
# ### Base: dias úteis do mês (uma linha por mês)

# %%
# dias úteis do mês (uma linha por mês)
dias_uteis_mes = (
    dpm.loc[:, ["MES", "MES_LABEL", "DIAS_PREVISTOS"]]
       .rename(columns={"DIAS_PREVISTOS": "DIAS_UTEIS_MES"})
       .drop_duplicates(subset=["MES"])
)

# %% [markdown]
# ### Headcount do mês (qtde de colaboradores com qualquer registro no mês)

# %%
# headcount do mês (empregados com qualquer registro no mês)
headcount_mes = (
    tmp.groupby(["MES", "MES_LABEL"], as_index=False)["NOMES"]
       .nunique()
       .rename(columns={"NOMES": "HEADCOUNT_MES"})
)

# %% [markdown]
# ### Ausências totais do mês

# %%
# ausências totais do mês
ausencias_totais_mes = (
    tmp.groupby(["MES", "MES_LABEL"], as_index=False)["DIAS_AUSENTES"]
       .sum()
       .rename(columns={"DIAS_AUSENTES": "DIAS_AUSENTES_TOTAL"})
)

# %% [markdown]
# ### Junção das bases e normalização de tipos

# %%
resumo_geral_mensal = (
    dias_uteis_mes
      .merge(headcount_mes, on=["MES", "MES_LABEL"], how="left")
      .merge(ausencias_totais_mes, on=["MES", "MES_LABEL"], how="left")
)

resumo_geral_mensal["HEADCOUNT_MES"]      = pd.to_numeric(resumo_geral_mensal["HEADCOUNT_MES"], errors="coerce").fillna(0).astype(int)
resumo_geral_mensal["DIAS_UTEIS_MES"]     = pd.to_numeric(resumo_geral_mensal["DIAS_UTEIS_MES"], errors="coerce").astype(float)
resumo_geral_mensal["DIAS_AUSENTES_TOTAL"]= pd.to_numeric(resumo_geral_mensal["DIAS_AUSENTES_TOTAL"], errors="coerce").fillna(0).astype(float)

# %% [markdown]
# ### Calculo = Ausencias / Presencias_mes

# %%
resumo_geral_mensal["PRESENCAS_TOTAIS"] = (
    resumo_geral_mensal["DIAS_UTEIS_MES"] * resumo_geral_mensal["HEADCOUNT_MES"]
).astype(float)

resumo_geral_mensal["ABSENTEISMO_GERAL_%"] = np.where(
    resumo_geral_mensal["PRESENCAS_TOTAIS"] > 0,
    (resumo_geral_mensal["DIAS_AUSENTES_TOTAL"] / resumo_geral_mensal["PRESENCAS_TOTAIS"]) * 100.0,
    np.nan
)
resumo_geral_mensal["ABSENTEISMO_GERAL_%"] = (
    pd.to_numeric(resumo_geral_mensal["ABSENTEISMO_GERAL_%"], errors="coerce")
      .astype(float)
      .round(2)
)

# %% [markdown]
# ### Agregação mensal geral
#
# Objetivo: gerar o resumo geral por mês:

# %%
resumo_geral_mensal = (
    resumo_geral_mensal
      .sort_values("MES")
      .reset_index(drop=True)[
          ["MES","MES_LABEL","DIAS_UTEIS_MES","HEADCOUNT_MES","PRESENCAS_TOTAIS","DIAS_AUSENTES_TOTAL","ABSENTEISMO_GERAL_%"]
      ]
)

# %% [markdown]
# ### Resultado Mes

# %%
pd.set_option('display.max_rows', None)

display(tabela_mensal)

display(resumo_geral_mensal)
# Out:
#                                       NOMES      MES  DIAS_AUSENTES MES_LABEL  \
# 0                ANA GOMES PINTO DOS SANTOS  2025-08              0  Aug/2025
# 1                ANA GOMES PINTO DOS SANTOS  2025-09              0  Sep/2025
# 2                ANA GOMES PINTO DOS SANTOS  2025-10              0  Oct/2025
# 3                ANA GOMES PINTO DOS SANTOS  2025-11              0  Nov/2025
# 4                ANA GOMES PINTO DOS SANTOS  2025-12              0  Dec/2025
# 5                ANA GOMES PINTO DOS SANTOS  2026-01              0  Jan/2026
# 6                 ANA LIMA DANTAS DE VIEIRA  2025-08              0  Aug/2025
# 7                 ANA LIMA DANTAS DE VIEIRA  2025-09              0  Sep/2025
# 8                 ANA LIMA DANTAS DE VIEIRA  2025-10              1  Oct/2025
# 9                 ANA LIMA DANTAS DE VIEIRA  2025-11              0  Nov/2025
# 10                ANA LIMA DANTAS DE VIEIRA  2025-12              1  Dec/2025
# 11                ANA LIMA DANTAS DE VIEIRA  2026-01              0  Jan/2026
# 12             ANA RIBEIRO PINTO DE RIBEIRO  2025-08              0  Aug/2025
# 13             ANA RIBEIRO PINTO DE RIBEIRO  2025-09              0  Sep/2025
# 14             ANA RIBEIRO PINTO DE RIBEIRO  2025-10              0  Oct/2025
# 15             ANA RIBEIRO PINTO DE RIBEIRO  2025-11              0  Nov/2025
# 16             ANA RIBEIRO PINTO DE RIBEIRO  2025-12              0  Dec/2025
# 17             ANA RIBEIRO PINTO DE RIBEIRO  2026-01              0  Jan/2026
# 18           ANA TEIXEIRA PINTO DE FERREIRA  2025-08              0  Aug/2025
# 19           ANA TEIXEIRA PINTO DE FERREIRA  2025-09              0  Sep/2025
# 20           ANA TEIXEIRA PINTO DE FERREIRA  2025-10              0  Oct/2025
# 21           ANA TEIXEIRA PINTO DE FERREIRA  2025-11              0  Nov/2025
# 22           ANA TEIXEIRA PINTO DE FERREIRA  2025-12              0  Dec/2025
# 23           ANA TEIXEIRA PINTO DE FERREIRA  2026-01              0  Jan/2026
# 24         BEATRIZ FERREIRA CAMPOS DE MOURA  2025-08              0  Aug/2025
# 25         BEATRIZ FERREIRA CAMPOS DE MOURA  2025-09              0  Sep/2025
# 26         BEATRIZ FERREIRA CAMPOS DE MOURA  2025-10              0  Oct/2025
# 27         BEATRIZ FERREIRA CAMPOS DE MOURA  2025-11              0  Nov/2025
# 28         BEATRIZ FERREIRA CAMPOS DE MOURA  2025-12              0  Dec/2025
# 29         BEATRIZ FERREIRA CAMPOS DE MOURA  2026-01              0  Jan/2026
# 30          BEATRIZ SOUZA MORAES DOS SANTOS  2025-08              0  Aug/2025
# 31          BEATRIZ SOUZA MORAES DOS SANTOS  2025-09              0  Sep/2025
# 32          BEATRIZ SOUZA MORAES DOS SANTOS  2025-10              0  Oct/2025
# 33          BEATRIZ SOUZA MORAES DOS SANTOS  2025-11              0  Nov/2025
# 34          BEATRIZ SOUZA MORAES DOS SANTOS  2025-12              0  Dec/2025
# 35          BEATRIZ SOUZA MORAES DOS SANTOS  2026-01              0  Jan/2026
# 36          BRUNO NOGUEIRA MARTINS DE SOUZA  2025-08              0  Aug/2025
# 37          BRUNO NOGUEIRA MARTINS DE SOUZA  2025-09              0  Sep/2025
# 38          BRUNO NOGUEIRA MARTINS DE SOUZA  2025-10              1  Oct/2025
# 39          BRUNO NOGUEIRA MARTINS DE SOUZA  2025-11              1  Nov/2025
# 40          BRUNO NOGUEIRA MARTINS DE SOUZA  2025-12              0  Dec/2025
# 41          BRUNO NOGUEIRA MARTINS DE SOUZA  2026-01              0  Jan/2026
# 42        BRUNO SANTOS BARBOSA DE RODRIGUES  2025-08              0  Aug/2025
# 43        BRUNO SANTOS BARBOSA DE RODRIGUES  2025-09              1  Sep/2025
# 44        BRUNO SANTOS BARBOSA DE RODRIGUES  2025-10              0  Oct/2025
# 45        BRUNO SANTOS BARBOSA DE RODRIGUES  2025-11              0  Nov/2025
# 46        BRUNO SANTOS BARBOSA DE RODRIGUES  2025-12              0  Dec/2025
# 47        BRUNO SANTOS BARBOSA DE RODRIGUES  2026-01              1  Jan/2026
# 48            BRUNO SILVA PINTO DE OLIVEIRA  2025-08              0  Aug/2025
# 49            BRUNO SILVA PINTO DE OLIVEIRA  2025-09              0  Sep/2025
# 50            BRUNO SILVA PINTO DE OLIVEIRA  2025-10              0  Oct/2025
# 51            BRUNO SILVA PINTO DE OLIVEIRA  2025-11              0  Nov/2025
# 52            BRUNO SILVA PINTO DE OLIVEIRA  2025-12              0  Dec/2025
# 53            BRUNO SILVA PINTO DE OLIVEIRA  2026-01              0  Jan/2026
# 54          CAMILA GOMES BATISTA DE RIBEIRO  2025-08              0  Aug/2025
# 55          CAMILA GOMES BATISTA DE RIBEIRO  2025-09              0  Sep/2025
# 56          CAMILA GOMES BATISTA DE RIBEIRO  2025-10              0  Oct/2025
# 57          CAMILA GOMES BATISTA DE RIBEIRO  2025-11              1  Nov/2025
# 58          CAMILA GOMES BATISTA DE RIBEIRO  2025-12              3  Dec/2025
# 59          CAMILA GOMES BATISTA DE RIBEIRO  2026-01              0  Jan/2026
# 60       CAMILA PEREIRA BARROS DE RODRIGUES  2025-08              0  Aug/2025
# 61       CAMILA PEREIRA BARROS DE RODRIGUES  2025-09              0  Sep/2025
# 62       CAMILA PEREIRA BARROS DE RODRIGUES  2025-10              0  Oct/2025
# 63       CAMILA PEREIRA BARROS DE RODRIGUES  2025-11              0  Nov/2025
# 64       CAMILA PEREIRA BARROS DE RODRIGUES  2025-12              0  Dec/2025
# 65       CAMILA PEREIRA BARROS DE RODRIGUES  2026-01              0  Jan/2026
# 66         CAMILA SANTOS PINTO DE RODRIGUES  2025-08              0  Aug/2025
# 67         CAMILA SANTOS PINTO DE RODRIGUES  2025-09              0  Sep/2025
# 68         CAMILA SANTOS PINTO DE RODRIGUES  2025-10              0  Oct/2025
# 69         CAMILA SANTOS PINTO DE RODRIGUES  2025-11              0  Nov/2025
# 70         CAMILA SANTOS PINTO DE RODRIGUES  2025-12              0  Dec/2025
# 71         CAMILA SANTOS PINTO DE RODRIGUES  2026-01              0  Jan/2026
# 72         CAMILA SOARES PEREIRA DE BARBOSA  2025-08              0  Aug/2025
# 73         CAMILA SOARES PEREIRA DE BARBOSA  2025-09              0  Sep/2025
# 74         CAMILA SOARES PEREIRA DE BARBOSA  2025-10              1  Oct/2025
# 75         CAMILA SOARES PEREIRA DE BARBOSA  2025-11              0  Nov/2025
# 76         CAMILA SOARES PEREIRA DE BARBOSA  2025-12              0  Dec/2025
# 77         CAMILA SOARES PEREIRA DE BARBOSA  2026-01              2  Jan/2026
# 78         CARLA FREITAS RIBEIRO DE ALMEIDA  2025-08              0  Aug/2025
# 79         CARLA FREITAS RIBEIRO DE ALMEIDA  2025-09              0  Sep/2025
# 80         CARLA FREITAS RIBEIRO DE ALMEIDA  2025-10              0  Oct/2025
# 81         CARLA FREITAS RIBEIRO DE ALMEIDA  2025-11              0  Nov/2025
# 82         CARLA FREITAS RIBEIRO DE ALMEIDA  2025-12              0  Dec/2025
# 83         CARLA FREITAS RIBEIRO DE ALMEIDA  2026-01              0  Jan/2026
# 84            CARLA SANTOS DANTAS DE ARAUJO  2025-08              0  Aug/2025
# 85            CARLA SANTOS DANTAS DE ARAUJO  2025-09              0  Sep/2025
# 86            CARLA SANTOS DANTAS DE ARAUJO  2025-10              0  Oct/2025
# 87            CARLA SANTOS DANTAS DE ARAUJO  2025-11              0  Nov/2025
# 88            CARLA SANTOS DANTAS DE ARAUJO  2025-12              0  Dec/2025
# 89            CARLA SANTOS DANTAS DE ARAUJO  2026-01              0  Jan/2026
# 90   CAROLINA FERREIRA CARVALHO DE OLIVEIRA  2025-08              0  Aug/2025
# 91   CAROLINA FERREIRA CARVALHO DE OLIVEIRA  2025-09              0  Sep/2025
# 92   CAROLINA FERREIRA CARVALHO DE OLIVEIRA  2025-10              0  Oct/2025
# 93   CAROLINA FERREIRA CARVALHO DE OLIVEIRA  2025-11              0  Nov/2025
# 94   CAROLINA FERREIRA CARVALHO DE OLIVEIRA  2025-12              0  Dec/2025
# 95   CAROLINA FERREIRA CARVALHO DE OLIVEIRA  2026-01              0  Jan/2026
# 96        CAROLINA LOPES ARAUJO DE OLIVEIRA  2025-08              0  Aug/2025
# 97        CAROLINA LOPES ARAUJO DE OLIVEIRA  2025-09              0  Sep/2025
# 98        CAROLINA LOPES ARAUJO DE OLIVEIRA  2025-10              0  Oct/2025
# 99        CAROLINA LOPES ARAUJO DE OLIVEIRA  2025-11              0  Nov/2025
# 100       CAROLINA LOPES ARAUJO DE OLIVEIRA  2025-12              0  Dec/2025
# 101       CAROLINA LOPES ARAUJO DE OLIVEIRA  2026-01              0  Jan/2026
# 102         CAROLINA PINTO SILVA DE RIBEIRO  2025-08              0  Aug/2025
# 103         CAROLINA PINTO SILVA DE RIBEIRO  2025-09              0  Sep/2025
# 104         CAROLINA PINTO SILVA DE RIBEIRO  2025-10              0  Oct/2025
# 105         CAROLINA PINTO SILVA DE RIBEIRO  2025-11              0  Nov/2025
# 106         CAROLINA PINTO SILVA DE RIBEIRO  2025-12              0  Dec/2025
# 107         CAROLINA PINTO SILVA DE RIBEIRO  2026-01              0  Jan/2026
# 108      CAROLINA SANTOS MARTINS DE SANTANA  2025-08              0  Aug/2025
# 109      CAROLINA SANTOS MARTINS DE SANTANA  2025-09              0  Sep/2025
# 110      CAROLINA SANTOS MARTINS DE SANTANA  2025-10              0  Oct/2025
# 111      CAROLINA SANTOS MARTINS DE SANTANA  2025-11              0  Nov/2025
# 112      CAROLINA SANTOS MARTINS DE SANTANA  2025-12              0  Dec/2025
# 113      CAROLINA SANTOS MARTINS DE SANTANA  2026-01              0  Jan/2026
# 114      CAROLINA SOUZA OLIVEIRA DOS SANTOS  2025-08              0  Aug/2025
# 115      CAROLINA SOUZA OLIVEIRA DOS SANTOS  2025-09              0  Sep/2025
# 116      CAROLINA SOUZA OLIVEIRA DOS SANTOS  2025-10              0  Oct/2025
# 117      CAROLINA SOUZA OLIVEIRA DOS SANTOS  2025-11              0  Nov/2025
# 118      CAROLINA SOUZA OLIVEIRA DOS SANTOS  2025-12              0  Dec/2025
# 119      CAROLINA SOUZA OLIVEIRA DOS SANTOS  2026-01              0  Jan/2026
# 120          CLARA BARBOSA MELO DE TEIXEIRA  2025-08              0  Aug/2025
# 121          CLARA BARBOSA MELO DE TEIXEIRA  2025-09              0  Sep/2025
# 122          CLARA BARBOSA MELO DE TEIXEIRA  2025-10              0  Oct/2025
# 123          CLARA BARBOSA MELO DE TEIXEIRA  2025-11              0  Nov/2025
# 124          CLARA BARBOSA MELO DE TEIXEIRA  2025-12              0  Dec/2025
# 125          CLARA BARBOSA MELO DE TEIXEIRA  2026-01              0  Jan/2026
# 126          CLARA CUNHA ROCHA DE RODRIGUES  2025-08              0  Aug/2025
# 127          CLARA CUNHA ROCHA DE RODRIGUES  2025-09              0  Sep/2025
# 128          CLARA CUNHA ROCHA DE RODRIGUES  2025-10              0  Oct/2025
# 129          CLARA CUNHA ROCHA DE RODRIGUES  2025-11              0  Nov/2025
# 130          CLARA CUNHA ROCHA DE RODRIGUES  2025-12              0  Dec/2025
# 131          CLARA CUNHA ROCHA DE RODRIGUES  2026-01              0  Jan/2026
# 132              CLARA SANTOS ALVES DE LIMA  2025-08              0  Aug/2025
# 133              CLARA SANTOS ALVES DE LIMA  2025-09              0  Sep/2025
# 134              CLARA SANTOS ALVES DE LIMA  2025-10              0  Oct/2025
# 135              CLARA SANTOS ALVES DE LIMA  2025-11              0  Nov/2025
# 136              CLARA SANTOS ALVES DE LIMA  2025-12              0  Dec/2025
# 137              CLARA SANTOS ALVES DE LIMA  2026-01              0  Jan/2026
# 138               CLARA SOUZA LIMA DE ROCHA  2025-08              0  Aug/2025
# 139               CLARA SOUZA LIMA DE ROCHA  2025-09              0  Sep/2025
# 140               CLARA SOUZA LIMA DE ROCHA  2025-10              0  Oct/2025
# 141               CLARA SOUZA LIMA DE ROCHA  2025-11              0  Nov/2025
# 142               CLARA SOUZA LIMA DE ROCHA  2025-12              0  Dec/2025
# 143               CLARA SOUZA LIMA DE ROCHA  2026-01              0  Jan/2026
# 144     DANIEL BEZERRA TEIXEIRA DE TEIXEIRA  2025-08              1  Aug/2025
# 145     DANIEL BEZERRA TEIXEIRA DE TEIXEIRA  2025-09              1  Sep/2025
# 146     DANIEL BEZERRA TEIXEIRA DE TEIXEIRA  2025-10              0  Oct/2025
# 147     DANIEL BEZERRA TEIXEIRA DE TEIXEIRA  2025-11              0  Nov/2025
# 148     DANIEL BEZERRA TEIXEIRA DE TEIXEIRA  2025-12              0  Dec/2025
# 149     DANIEL BEZERRA TEIXEIRA DE TEIXEIRA  2026-01              1  Jan/2026
# 150          DANIEL FREITAS MELO DOS SANTOS  2025-08              0  Aug/2025
# 151          DANIEL FREITAS MELO DOS SANTOS  2025-09              0  Sep/2025
# 152          DANIEL FREITAS MELO DOS SANTOS  2025-10              0  Oct/2025
# 153          DANIEL FREITAS MELO DOS SANTOS  2025-11              0  Nov/2025
# 154          DANIEL FREITAS MELO DOS SANTOS  2025-12              0  Dec/2025
# 155          DANIEL FREITAS MELO DOS SANTOS  2026-01              0  Jan/2026
# 156        DANIEL VIEIRA ALMEIDA DE SANTANA  2025-08              1  Aug/2025
# 157        DANIEL VIEIRA ALMEIDA DE SANTANA  2025-09              1  Sep/2025
# 158        DANIEL VIEIRA ALMEIDA DE SANTANA  2025-10              2  Oct/2025
# 159        DANIEL VIEIRA ALMEIDA DE SANTANA  2025-11              0  Nov/2025
# 160        DANIEL VIEIRA ALMEIDA DE SANTANA  2025-12              0  Dec/2025
# 161        DANIEL VIEIRA ALMEIDA DE SANTANA  2026-01              1  Jan/2026
# 162        DANIELA COSTA RIBEIRO DE ALMEIDA  2025-08              0  Aug/2025
# 163        DANIELA COSTA RIBEIRO DE ALMEIDA  2025-09              0  Sep/2025
# 164        DANIELA COSTA RIBEIRO DE ALMEIDA  2025-10              0  Oct/2025
# 165        DANIELA COSTA RIBEIRO DE ALMEIDA  2025-11              0  Nov/2025
# 166        DANIELA COSTA RIBEIRO DE ALMEIDA  2025-12              0  Dec/2025
# 167        DANIELA COSTA RIBEIRO DE ALMEIDA  2026-01              0  Jan/2026
# 168          DAVI FERREIRA COSTA DE BARBOSA  2025-08              0  Aug/2025
# 169          DAVI FERREIRA COSTA DE BARBOSA  2025-09              0  Sep/2025
# 170          DAVI FERREIRA COSTA DE BARBOSA  2025-10              0  Oct/2025
# 171          DAVI FERREIRA COSTA DE BARBOSA  2025-11              0  Nov/2025
# 172          DAVI FERREIRA COSTA DE BARBOSA  2025-12              0  Dec/2025
# 173          DAVI FERREIRA COSTA DE BARBOSA  2026-01              0  Jan/2026
# 174           DAVI SOARES BARBOSA DE VIEIRA  2025-08              1  Aug/2025
# 175           DAVI SOARES BARBOSA DE VIEIRA  2025-09              0  Sep/2025
# 176           DAVI SOARES BARBOSA DE VIEIRA  2025-10              0  Oct/2025
# 177           DAVI SOARES BARBOSA DE VIEIRA  2025-11              0  Nov/2025
# 178           DAVI SOARES BARBOSA DE VIEIRA  2025-12              0  Dec/2025
# 179           DAVI SOARES BARBOSA DE VIEIRA  2026-01              3  Jan/2026
# 180        DIEGO BATISTA BEZERRA DOS SANTOS  2025-08              0  Aug/2025
# 181        DIEGO BATISTA BEZERRA DOS SANTOS  2025-09              0  Sep/2025
# 182        DIEGO BATISTA BEZERRA DOS SANTOS  2025-10              0  Oct/2025
# 183        DIEGO BATISTA BEZERRA DOS SANTOS  2025-11              0  Nov/2025
# 184        DIEGO BATISTA BEZERRA DOS SANTOS  2025-12              0  Dec/2025
# 185        DIEGO BATISTA BEZERRA DOS SANTOS  2026-01              0  Jan/2026
# 186       DIEGO CARDOSO MENDES DE RODRIGUES  2025-08              0  Aug/2025
# 187       DIEGO CARDOSO MENDES DE RODRIGUES  2025-09              0  Sep/2025
# 188       DIEGO CARDOSO MENDES DE RODRIGUES  2025-10              0  Oct/2025
# 189       DIEGO CARDOSO MENDES DE RODRIGUES  2025-11              0  Nov/2025
# 190       DIEGO CARDOSO MENDES DE RODRIGUES  2025-12              0  Dec/2025
# 191       DIEGO CARDOSO MENDES DE RODRIGUES  2026-01              0  Jan/2026
# 192            DIEGO COSTA ARAUJO DE SANTOS  2025-08              0  Aug/2025
# 193            DIEGO COSTA ARAUJO DE SANTOS  2025-09              0  Sep/2025
# 194            DIEGO COSTA ARAUJO DE SANTOS  2025-10              0  Oct/2025
# 195            DIEGO COSTA ARAUJO DE SANTOS  2025-11              0  Nov/2025
# 196            DIEGO COSTA ARAUJO DE SANTOS  2025-12              0  Dec/2025
# 197            DIEGO COSTA ARAUJO DE SANTOS  2026-01              0  Jan/2026
# 198           DIEGO SANTOS VIEIRA DE VIEIRA  2025-08              0  Aug/2025
# 199           DIEGO SANTOS VIEIRA DE VIEIRA  2025-09              1  Sep/2025
# 200           DIEGO SANTOS VIEIRA DE VIEIRA  2025-10              0  Oct/2025
# 201           DIEGO SANTOS VIEIRA DE VIEIRA  2025-11              1  Nov/2025
# 202           DIEGO SANTOS VIEIRA DE VIEIRA  2025-12              1  Dec/2025
# 203           DIEGO SANTOS VIEIRA DE VIEIRA  2026-01              1  Jan/2026
# 204          DOUGLAS ALVES BARBOSA DA SILVA  2025-08              0  Aug/2025
# 205          DOUGLAS ALVES BARBOSA DA SILVA  2025-09              0  Sep/2025
# 206          DOUGLAS ALVES BARBOSA DA SILVA  2025-10              0  Oct/2025
# 207          DOUGLAS ALVES BARBOSA DA SILVA  2025-11              0  Nov/2025
# 208          DOUGLAS ALVES BARBOSA DA SILVA  2025-12              0  Dec/2025
# 209          DOUGLAS ALVES BARBOSA DA SILVA  2026-01              0  Jan/2026
# 210                DOUGLAS DAVY DE OLIVEIRA  2025-08              0  Aug/2025
# 211                DOUGLAS DAVY DE OLIVEIRA  2025-09              0  Sep/2025
# 212                DOUGLAS DAVY DE OLIVEIRA  2025-10              0  Oct/2025
# 213                DOUGLAS DAVY DE OLIVEIRA  2025-11              0  Nov/2025
# 214                DOUGLAS DAVY DE OLIVEIRA  2025-12              0  Dec/2025
# 215                DOUGLAS DAVY DE OLIVEIRA  2026-01              0  Jan/2026
# 216         DOUGLAS LOPES DANTAS DOS SANTOS  2025-08              0  Aug/2025
# 217         DOUGLAS LOPES DANTAS DOS SANTOS  2025-09              0  Sep/2025
# 218         DOUGLAS LOPES DANTAS DOS SANTOS  2025-10              0  Oct/2025
# 219         DOUGLAS LOPES DANTAS DOS SANTOS  2025-11              0  Nov/2025
# 220         DOUGLAS LOPES DANTAS DOS SANTOS  2025-12              0  Dec/2025
# 221         DOUGLAS LOPES DANTAS DOS SANTOS  2026-01              0  Jan/2026
# 222          DOUGLAS SOUZA MARTINS DA CUNHA  2025-08              0  Aug/2025
# 223          DOUGLAS SOUZA MARTINS DA CUNHA  2025-09              0  Sep/2025
# 224          DOUGLAS SOUZA MARTINS DA CUNHA  2025-10              0  Oct/2025
# 225          DOUGLAS SOUZA MARTINS DA CUNHA  2025-11              0  Nov/2025
# 226          DOUGLAS SOUZA MARTINS DA CUNHA  2025-12              0  Dec/2025
# 227          DOUGLAS SOUZA MARTINS DA CUNHA  2026-01              0  Jan/2026
# 228            ELISA COSTA FREITAS DA SILVA  2025-08              0  Aug/2025
# 229            ELISA COSTA FREITAS DA SILVA  2025-09              0  Sep/2025
# 230            ELISA COSTA FREITAS DA SILVA  2025-10              0  Oct/2025
# 231            ELISA COSTA FREITAS DA SILVA  2025-11              0  Nov/2025
# 232            ELISA COSTA FREITAS DA SILVA  2025-12              0  Dec/2025
# 233            ELISA COSTA FREITAS DA SILVA  2026-01              0  Jan/2026
# 234             ELISA MORAES LOPES DE ROCHA  2025-08              1  Aug/2025
# 235             ELISA MORAES LOPES DE ROCHA  2025-09              2  Sep/2025
# 236             ELISA MORAES LOPES DE ROCHA  2025-10              0  Oct/2025
# 237             ELISA MORAES LOPES DE ROCHA  2025-11              2  Nov/2025
# 238             ELISA MORAES LOPES DE ROCHA  2025-12              0  Dec/2025
# 239             ELISA MORAES LOPES DE ROCHA  2026-01              0  Jan/2026
# 240          ELISA SILVA RODRIGUES DA CUNHA  2025-08              0  Aug/2025
# 241          ELISA SILVA RODRIGUES DA CUNHA  2025-09              1  Sep/2025
# 242          ELISA SILVA RODRIGUES DA CUNHA  2025-10              0  Oct/2025
# 243          ELISA SILVA RODRIGUES DA CUNHA  2025-11              1  Nov/2025
# 244          ELISA SILVA RODRIGUES DA CUNHA  2025-12              1  Dec/2025
# 245          ELISA SILVA RODRIGUES DA CUNHA  2026-01              1  Jan/2026
# 246          EMANUELA ALVES SANTOS DE MOURA  2025-08              0  Aug/2025
# 247          EMANUELA ALVES SANTOS DE MOURA  2025-09              0  Sep/2025
# 248          EMANUELA ALVES SANTOS DE MOURA  2025-10              0  Oct/2025
# 249          EMANUELA ALVES SANTOS DE MOURA  2025-11              0  Nov/2025
# 250          EMANUELA ALVES SANTOS DE MOURA  2025-12              0  Dec/2025
# 251          EMANUELA ALVES SANTOS DE MOURA  2026-01              0  Jan/2026
# 252      EMANUELA BATISTA BEZERRA DE VIEIRA  2025-08              0  Aug/2025
# 253      EMANUELA BATISTA BEZERRA DE VIEIRA  2025-09              0  Sep/2025
# 254      EMANUELA BATISTA BEZERRA DE VIEIRA  2025-10              0  Oct/2025
# 255      EMANUELA BATISTA BEZERRA DE VIEIRA  2025-11              0  Nov/2025
# 256      EMANUELA BATISTA BEZERRA DE VIEIRA  2025-12              0  Dec/2025
# 257      EMANUELA BATISTA BEZERRA DE VIEIRA  2026-01              0  Jan/2026
# 258          EMANUELA COSTA DIAS DOS SANTOS  2025-08              0  Aug/2025
# 259          EMANUELA COSTA DIAS DOS SANTOS  2025-09              0  Sep/2025
# 260          EMANUELA COSTA DIAS DOS SANTOS  2025-10              0  Oct/2025
# 261          EMANUELA COSTA DIAS DOS SANTOS  2025-11              0  Nov/2025
# 262          EMANUELA COSTA DIAS DOS SANTOS  2025-12              0  Dec/2025
# 263          EMANUELA COSTA DIAS DOS SANTOS  2026-01              0  Jan/2026
# 264        EMANUELA CUNHA PINTO DE TEIXEIRA  2025-08              0  Aug/2025
# 265        EMANUELA CUNHA PINTO DE TEIXEIRA  2025-09              2  Sep/2025
# 266        EMANUELA CUNHA PINTO DE TEIXEIRA  2025-10              1  Oct/2025
# 267        EMANUELA CUNHA PINTO DE TEIXEIRA  2025-11              1  Nov/2025
# 268        EMANUELA CUNHA PINTO DE TEIXEIRA  2025-12              0  Dec/2025
# 269        EMANUELA CUNHA PINTO DE TEIXEIRA  2026-01              0  Jan/2026
# 270       EMANUELA RODRIGUES BRAGA DA SILVA  2025-08              0  Aug/2025
# 271       EMANUELA RODRIGUES BRAGA DA SILVA  2025-09              0  Sep/2025
# 272       EMANUELA RODRIGUES BRAGA DA SILVA  2025-10              0  Oct/2025
# 273       EMANUELA RODRIGUES BRAGA DA SILVA  2025-11              0  Nov/2025
# 274       EMANUELA RODRIGUES BRAGA DA SILVA  2025-12              0  Dec/2025
# 275       EMANUELA RODRIGUES BRAGA DA SILVA  2026-01              0  Jan/2026
# 276             ENZO AMARAL PINTO DE SANTOS  2025-08              0  Aug/2025
# 277             ENZO AMARAL PINTO DE SANTOS  2025-09              3  Sep/2025
# 278             ENZO AMARAL PINTO DE SANTOS  2025-10              0  Oct/2025
# 279             ENZO AMARAL PINTO DE SANTOS  2025-11              1  Nov/2025
# 280             ENZO AMARAL PINTO DE SANTOS  2025-12              0  Dec/2025
# 281             ENZO AMARAL PINTO DE SANTOS  2026-01              0  Jan/2026
# 282          ENZO MOURA RODRIGUES DE ARAUJO  2025-08              1  Aug/2025
# 283          ENZO MOURA RODRIGUES DE ARAUJO  2025-09              1  Sep/2025
# 284          ENZO MOURA RODRIGUES DE ARAUJO  2025-10              0  Oct/2025
# 285          ENZO MOURA RODRIGUES DE ARAUJO  2025-11              0  Nov/2025
# 286          ENZO MOURA RODRIGUES DE ARAUJO  2025-12              0  Dec/2025
# 287          ENZO MOURA RODRIGUES DE ARAUJO  2026-01              0  Jan/2026
# 288          ENZO VIEIRA BEZERRA DE RIBEIRO  2025-08              2  Aug/2025
# 289          ENZO VIEIRA BEZERRA DE RIBEIRO  2025-09              0  Sep/2025
# 290          ENZO VIEIRA BEZERRA DE RIBEIRO  2025-10              2  Oct/2025
# 291          ENZO VIEIRA BEZERRA DE RIBEIRO  2025-11              1  Nov/2025
# 292          ENZO VIEIRA BEZERRA DE RIBEIRO  2025-12              0  Dec/2025
# 293          ENZO VIEIRA BEZERRA DE RIBEIRO  2026-01              0  Jan/2026
# 294          ENZO VIEIRA CARDOSO DE RIBEIRO  2025-08              1  Aug/2025
# 295          ENZO VIEIRA CARDOSO DE RIBEIRO  2025-09              2  Sep/2025
# 296          ENZO VIEIRA CARDOSO DE RIBEIRO  2025-10              0  Oct/2025
# 297          ENZO VIEIRA CARDOSO DE RIBEIRO  2025-11              0  Nov/2025
# 298          ENZO VIEIRA CARDOSO DE RIBEIRO  2025-12              0  Dec/2025
# 299          ENZO VIEIRA CARDOSO DE RIBEIRO  2026-01              0  Jan/2026
# 300         ERIC AMARAL FERREIRA DE RIBEIRO  2025-08              0  Aug/2025
# 301         ERIC AMARAL FERREIRA DE RIBEIRO  2025-09              0  Sep/2025
# 302         ERIC AMARAL FERREIRA DE RIBEIRO  2025-10              0  Oct/2025
# 303         ERIC AMARAL FERREIRA DE RIBEIRO  2025-11              0  Nov/2025
# 304         ERIC AMARAL FERREIRA DE RIBEIRO  2025-12              0  Dec/2025
# 305         ERIC AMARAL FERREIRA DE RIBEIRO  2026-01              0  Jan/2026
# 306         FELIPE ARAUJO FERREIRA DE ROCHA  2025-08              0  Aug/2025
# 307         FELIPE ARAUJO FERREIRA DE ROCHA  2025-09              0  Sep/2025
# 308         FELIPE ARAUJO FERREIRA DE ROCHA  2025-10              0  Oct/2025
# 309         FELIPE ARAUJO FERREIRA DE ROCHA  2025-11              0  Nov/2025
# 310         FELIPE ARAUJO FERREIRA DE ROCHA  2025-12              0  Dec/2025
# 311         FELIPE ARAUJO FERREIRA DE ROCHA  2026-01              0  Jan/2026
# 312          FELIPE COSTA MORAES DE RIBEIRO  2025-08              0  Aug/2025
# 313          FELIPE COSTA MORAES DE RIBEIRO  2025-09              0  Sep/2025
# 314          FELIPE COSTA MORAES DE RIBEIRO  2025-10              0  Oct/2025
# 315          FELIPE COSTA MORAES DE RIBEIRO  2025-11              0  Nov/2025
# 316          FELIPE COSTA MORAES DE RIBEIRO  2025-12              1  Dec/2025
# 317          FELIPE COSTA MORAES DE RIBEIRO  2026-01              1  Jan/2026
# 318         FELIPE SILVA FREITAS DE RIBEIRO  2025-08              0  Aug/2025
# 319         FELIPE SILVA FREITAS DE RIBEIRO  2025-09              0  Sep/2025
# 320         FELIPE SILVA FREITAS DE RIBEIRO  2025-10              0  Oct/2025
# 321         FELIPE SILVA FREITAS DE RIBEIRO  2025-11              0  Nov/2025
# 322         FELIPE SILVA FREITAS DE RIBEIRO  2025-12              0  Dec/2025
# 323         FELIPE SILVA FREITAS DE RIBEIRO  2026-01              0  Jan/2026
# 324          FERNANDA BEZERRA COSTA DE LIMA  2025-08              0  Aug/2025
# 325          FERNANDA BEZERRA COSTA DE LIMA  2025-09              0  Sep/2025
# 326          FERNANDA BEZERRA COSTA DE LIMA  2025-10              0  Oct/2025
# 327          FERNANDA BEZERRA COSTA DE LIMA  2025-11              0  Nov/2025
# 328          FERNANDA BEZERRA COSTA DE LIMA  2025-12              0  Dec/2025
# 329          FERNANDA BEZERRA COSTA DE LIMA  2026-01              0  Jan/2026
# 330         FERNANDA BRAGA DANTAS DE ARAUJO  2025-08              0  Aug/2025
# 331         FERNANDA BRAGA DANTAS DE ARAUJO  2025-09              2  Sep/2025
# 332         FERNANDA BRAGA DANTAS DE ARAUJO  2025-10              0  Oct/2025
# 333         FERNANDA BRAGA DANTAS DE ARAUJO  2025-11              1  Nov/2025
# 334         FERNANDA BRAGA DANTAS DE ARAUJO  2025-12              1  Dec/2025
# 335         FERNANDA BRAGA DANTAS DE ARAUJO  2026-01              1  Jan/2026
# 336       FERNANDA MORAES MENDES DE SANTANA  2025-08              0  Aug/2025
# 337       FERNANDA MORAES MENDES DE SANTANA  2025-09              0  Sep/2025
# 338       FERNANDA MORAES MENDES DE SANTANA  2025-10              1  Oct/2025
# 339       FERNANDA MORAES MENDES DE SANTANA  2025-11              1  Nov/2025
# 340       FERNANDA MORAES MENDES DE SANTANA  2025-12              0  Dec/2025
# 341       FERNANDA MORAES MENDES DE SANTANA  2026-01              1  Jan/2026
# 342       GABRIEL BEZERRA SOUZA DE TEIXEIRA  2025-08              0  Aug/2025
# 343       GABRIEL BEZERRA SOUZA DE TEIXEIRA  2025-09              1  Sep/2025
# 344       GABRIEL BEZERRA SOUZA DE TEIXEIRA  2025-10              0  Oct/2025
# 345       GABRIEL BEZERRA SOUZA DE TEIXEIRA  2025-11              0  Nov/2025
# 346       GABRIEL BEZERRA SOUZA DE TEIXEIRA  2025-12              0  Dec/2025
# 347       GABRIEL BEZERRA SOUZA DE TEIXEIRA  2026-01              1  Jan/2026
# 348         GABRIEL PINTO OLIVEIRA DA CUNHA  2025-08              0  Aug/2025
# 349         GABRIEL PINTO OLIVEIRA DA CUNHA  2025-09              0  Sep/2025
# 350         GABRIEL PINTO OLIVEIRA DA CUNHA  2025-10              0  Oct/2025
# 351         GABRIEL PINTO OLIVEIRA DA CUNHA  2025-11              0  Nov/2025
# 352         GABRIEL PINTO OLIVEIRA DA CUNHA  2025-12              0  Dec/2025
# 353         GABRIEL PINTO OLIVEIRA DA CUNHA  2026-01              0  Jan/2026
# 354    GABRIELA RIBEIRO BEZERRA DE OLIVEIRA  2025-08              0  Aug/2025
# 355    GABRIELA RIBEIRO BEZERRA DE OLIVEIRA  2025-09              0  Sep/2025
# 356    GABRIELA RIBEIRO BEZERRA DE OLIVEIRA  2025-10              0  Oct/2025
# 357    GABRIELA RIBEIRO BEZERRA DE OLIVEIRA  2025-11              0  Nov/2025
# 358    GABRIELA RIBEIRO BEZERRA DE OLIVEIRA  2025-12              0  Dec/2025
# 359    GABRIELA RIBEIRO BEZERRA DE OLIVEIRA  2026-01              0  Jan/2026
# 360         HEITOR CAMPOS BARBOSA DE SANTOS  2025-08              2  Aug/2025
# 361         HEITOR CAMPOS BARBOSA DE SANTOS  2025-09              0  Sep/2025
# 362         HEITOR CAMPOS BARBOSA DE SANTOS  2025-10              0  Oct/2025
# 363         HEITOR CAMPOS BARBOSA DE SANTOS  2025-11              0  Nov/2025
# 364         HEITOR CAMPOS BARBOSA DE SANTOS  2025-12              0  Dec/2025
# 365         HEITOR CAMPOS BARBOSA DE SANTOS  2026-01              0  Jan/2026
# 366      HEITOR CARDOSO CARVALHO DE RIBEIRO  2025-08              0  Aug/2025
# 367      HEITOR CARDOSO CARVALHO DE RIBEIRO  2025-09              0  Sep/2025
# 368      HEITOR CARDOSO CARVALHO DE RIBEIRO  2025-10              0  Oct/2025
# 369      HEITOR CARDOSO CARVALHO DE RIBEIRO  2025-11              0  Nov/2025
# 370      HEITOR CARDOSO CARVALHO DE RIBEIRO  2025-12              0  Dec/2025
# 371      HEITOR CARDOSO CARVALHO DE RIBEIRO  2026-01              0  Jan/2026
# 372        HEITOR DANTAS ALVES DE RODRIGUES  2025-08              0  Aug/2025
# 373        HEITOR DANTAS ALVES DE RODRIGUES  2025-09              1  Sep/2025
# 374        HEITOR DANTAS ALVES DE RODRIGUES  2025-10              0  Oct/2025
# 375        HEITOR DANTAS ALVES DE RODRIGUES  2025-11              1  Nov/2025
# 376        HEITOR DANTAS ALVES DE RODRIGUES  2025-12              0  Dec/2025
# 377        HEITOR DANTAS ALVES DE RODRIGUES  2026-01              0  Jan/2026
# 378       HEITOR FERREIRA MOURA DE OLIVEIRA  2025-08              0  Aug/2025
# 379       HEITOR FERREIRA MOURA DE OLIVEIRA  2025-09              0  Sep/2025
# 380       HEITOR FERREIRA MOURA DE OLIVEIRA  2025-10              0  Oct/2025
# 381       HEITOR FERREIRA MOURA DE OLIVEIRA  2025-11              0  Nov/2025
# 382       HEITOR FERREIRA MOURA DE OLIVEIRA  2025-12              0  Dec/2025
# 383       HEITOR FERREIRA MOURA DE OLIVEIRA  2026-01              0  Jan/2026
# 384        HEITOR LOPES ALMEIDA DE FERREIRA  2025-08              0  Aug/2025
# 385        HEITOR LOPES ALMEIDA DE FERREIRA  2025-09              0  Sep/2025
# 386        HEITOR LOPES ALMEIDA DE FERREIRA  2025-10              2  Oct/2025
# 387        HEITOR LOPES ALMEIDA DE FERREIRA  2025-11              1  Nov/2025
# 388        HEITOR LOPES ALMEIDA DE FERREIRA  2025-12              1  Dec/2025
# 389        HEITOR LOPES ALMEIDA DE FERREIRA  2026-01              0  Jan/2026
# 390       HELIO BEZERRA NOGUEIRA DE BARBOSA  2025-08              0  Aug/2025
# 391       HELIO BEZERRA NOGUEIRA DE BARBOSA  2025-09              0  Sep/2025
# 392       HELIO BEZERRA NOGUEIRA DE BARBOSA  2025-10              2  Oct/2025
# 393       HELIO BEZERRA NOGUEIRA DE BARBOSA  2025-11              0  Nov/2025
# 394       HELIO BEZERRA NOGUEIRA DE BARBOSA  2025-12              1  Dec/2025
# 395       HELIO BEZERRA NOGUEIRA DE BARBOSA  2026-01              0  Jan/2026
# 396    HENRIQUE ARAUJO NOGUEIRA DE FERREIRA  2025-08              0  Aug/2025
# 397    HENRIQUE ARAUJO NOGUEIRA DE FERREIRA  2025-09              0  Sep/2025
# 398    HENRIQUE ARAUJO NOGUEIRA DE FERREIRA  2025-10              0  Oct/2025
# 399    HENRIQUE ARAUJO NOGUEIRA DE FERREIRA  2025-11              0  Nov/2025
# 400    HENRIQUE ARAUJO NOGUEIRA DE FERREIRA  2025-12              0  Dec/2025
# 401    HENRIQUE ARAUJO NOGUEIRA DE FERREIRA  2026-01              0  Jan/2026
# 402       HENRIQUE BRAGA TEIXEIRA DE ARAUJO  2025-08              0  Aug/2025
# 403       HENRIQUE BRAGA TEIXEIRA DE ARAUJO  2025-09              0  Sep/2025
# 404       HENRIQUE BRAGA TEIXEIRA DE ARAUJO  2025-10              0  Oct/2025
# 405       HENRIQUE BRAGA TEIXEIRA DE ARAUJO  2025-11              0  Nov/2025
# 406       HENRIQUE BRAGA TEIXEIRA DE ARAUJO  2025-12              0  Dec/2025
# 407       HENRIQUE BRAGA TEIXEIRA DE ARAUJO  2026-01              0  Jan/2026
# 408        HENRIQUE PEREIRA ALMEIDA DE LIMA  2025-08              1  Aug/2025
# 409        HENRIQUE PEREIRA ALMEIDA DE LIMA  2025-09              1  Sep/2025
# 410        HENRIQUE PEREIRA ALMEIDA DE LIMA  2025-10              2  Oct/2025
# 411        HENRIQUE PEREIRA ALMEIDA DE LIMA  2025-11              0  Nov/2025
# 412        HENRIQUE PEREIRA ALMEIDA DE LIMA  2025-12              0  Dec/2025
# 413        HENRIQUE PEREIRA ALMEIDA DE LIMA  2026-01              0  Jan/2026
# 414           ISABELA SOUZA DIAS DE RIBEIRO  2025-08              0  Aug/2025
# 415           ISABELA SOUZA DIAS DE RIBEIRO  2025-09              0  Sep/2025
# 416           ISABELA SOUZA DIAS DE RIBEIRO  2025-10              0  Oct/2025
# 417           ISABELA SOUZA DIAS DE RIBEIRO  2025-11              1  Nov/2025
# 418           ISABELA SOUZA DIAS DE RIBEIRO  2025-12              0  Dec/2025
# 419           ISABELA SOUZA DIAS DE RIBEIRO  2026-01              1  Jan/2026
# 420        JOAO BARBOSA TEIXEIRA DE SANTANA  2025-08              2  Aug/2025
# 421        JOAO BARBOSA TEIXEIRA DE SANTANA  2025-09              0  Sep/2025
# 422        JOAO BARBOSA TEIXEIRA DE SANTANA  2025-10              1  Oct/2025
# 423        JOAO BARBOSA TEIXEIRA DE SANTANA  2025-11              1  Nov/2025
# 424        JOAO BARBOSA TEIXEIRA DE SANTANA  2025-12              0  Dec/2025
# 425        JOAO BARBOSA TEIXEIRA DE SANTANA  2026-01              0  Jan/2026
# 426         JOSE BEZERRA BARROS DE OLIVEIRA  2025-08              0  Aug/2025
# 427         JOSE BEZERRA BARROS DE OLIVEIRA  2025-09              0  Sep/2025
# 428         JOSE BEZERRA BARROS DE OLIVEIRA  2025-10              0  Oct/2025
# 429         JOSE BEZERRA BARROS DE OLIVEIRA  2025-11              0  Nov/2025
# 430         JOSE BEZERRA BARROS DE OLIVEIRA  2025-12              0  Dec/2025
# 431         JOSE BEZERRA BARROS DE OLIVEIRA  2026-01              0  Jan/2026
# 432              JOSE CAMPOS BRAGA DO CARMO  2025-08              0  Aug/2025
# 433              JOSE CAMPOS BRAGA DO CARMO  2025-09              0  Sep/2025
# 434              JOSE CAMPOS BRAGA DO CARMO  2025-10              0  Oct/2025
# 435              JOSE CAMPOS BRAGA DO CARMO  2025-11              0  Nov/2025
# 436              JOSE CAMPOS BRAGA DO CARMO  2025-12              0  Dec/2025
# 437              JOSE CAMPOS BRAGA DO CARMO  2026-01              0  Jan/2026
# 438              JOSE DANTAS ROCHA DA COSTA  2025-08              0  Aug/2025
# 439              JOSE DANTAS ROCHA DA COSTA  2025-09              0  Sep/2025
# 440              JOSE DANTAS ROCHA DA COSTA  2025-10              1  Oct/2025
# 441              JOSE DANTAS ROCHA DA COSTA  2025-11              0  Nov/2025
# 442              JOSE DANTAS ROCHA DA COSTA  2025-12              1  Dec/2025
# 443              JOSE DANTAS ROCHA DA COSTA  2026-01              0  Jan/2026
# 444            JOSE FREITAS VIEIRA DA SILVA  2025-08              0  Aug/2025
# 445            JOSE FREITAS VIEIRA DA SILVA  2025-09              0  Sep/2025
# 446            JOSE FREITAS VIEIRA DA SILVA  2025-10              0  Oct/2025
# 447            JOSE FREITAS VIEIRA DA SILVA  2025-11              0  Nov/2025
# 448            JOSE FREITAS VIEIRA DA SILVA  2025-12              0  Dec/2025
# 449            JOSE FREITAS VIEIRA DA SILVA  2026-01              0  Jan/2026
# 450         JULIA AMARAL ROCHA DE RODRIGUES  2025-08              2  Aug/2025
# 451         JULIA AMARAL ROCHA DE RODRIGUES  2025-09              1  Sep/2025
# 452         JULIA AMARAL ROCHA DE RODRIGUES  2025-10              1  Oct/2025
# 453         JULIA AMARAL ROCHA DE RODRIGUES  2025-11              0  Nov/2025
# 454         JULIA AMARAL ROCHA DE RODRIGUES  2025-12              0  Dec/2025
# 455         JULIA AMARAL ROCHA DE RODRIGUES  2026-01              1  Jan/2026
# 456       JULIANA BATISTA SANTANA DE VIEIRA  2025-08              0  Aug/2025
# 457       JULIANA BATISTA SANTANA DE VIEIRA  2025-09              0  Sep/2025
# 458       JULIANA BATISTA SANTANA DE VIEIRA  2025-10              0  Oct/2025
# 459       JULIANA BATISTA SANTANA DE VIEIRA  2025-11              0  Nov/2025
# 460       JULIANA BATISTA SANTANA DE VIEIRA  2025-12              0  Dec/2025
# 461       JULIANA BATISTA SANTANA DE VIEIRA  2026-01              0  Jan/2026
# 462            JULIANA DIAS PINTO DE VIEIRA  2025-08              0  Aug/2025
# 463            JULIANA DIAS PINTO DE VIEIRA  2025-09              0  Sep/2025
# 464            JULIANA DIAS PINTO DE VIEIRA  2025-10              0  Oct/2025
# 465            JULIANA DIAS PINTO DE VIEIRA  2025-11              0  Nov/2025
# 466            JULIANA DIAS PINTO DE VIEIRA  2025-12              0  Dec/2025
# 467            JULIANA DIAS PINTO DE VIEIRA  2026-01              0  Jan/2026
# 468           KARINA BARROS AMARAL DE MOURA  2025-08              1  Aug/2025
# 469           KARINA BARROS AMARAL DE MOURA  2025-09              0  Sep/2025
# 470           KARINA BARROS AMARAL DE MOURA  2025-10              0  Oct/2025
# 471           KARINA BARROS AMARAL DE MOURA  2025-11              0  Nov/2025
# 472           KARINA BARROS AMARAL DE MOURA  2025-12              0  Dec/2025
# 473           KARINA BARROS AMARAL DE MOURA  2026-01              1  Jan/2026
# 474        KARINA SANTANA MOURA DE FERREIRA  2025-08              0  Aug/2025
# 475        KARINA SANTANA MOURA DE FERREIRA  2025-09              0  Sep/2025
# 476        KARINA SANTANA MOURA DE FERREIRA  2025-10              0  Oct/2025
# 477        KARINA SANTANA MOURA DE FERREIRA  2025-11              0  Nov/2025
# 478        KARINA SANTANA MOURA DE FERREIRA  2025-12              0  Dec/2025
# 479        KARINA SANTANA MOURA DE FERREIRA  2026-01              0  Jan/2026
# 480          KARINA SANTOS COSTA DE ALMEIDA  2025-08              0  Aug/2025
# 481          KARINA SANTOS COSTA DE ALMEIDA  2025-09              0  Sep/2025
# 482          KARINA SANTOS COSTA DE ALMEIDA  2025-10              0  Oct/2025
# 483          KARINA SANTOS COSTA DE ALMEIDA  2025-11              0  Nov/2025
# 484          KARINA SANTOS COSTA DE ALMEIDA  2025-12              0  Dec/2025
# 485          KARINA SANTOS COSTA DE ALMEIDA  2026-01              0  Jan/2026
# 486       LARISSA ARAUJO MOURA DE RODRIGUES  2025-08              0  Aug/2025
# 487       LARISSA ARAUJO MOURA DE RODRIGUES  2025-09              0  Sep/2025
# 488       LARISSA ARAUJO MOURA DE RODRIGUES  2025-10              0  Oct/2025
# 489       LARISSA ARAUJO MOURA DE RODRIGUES  2025-11              0  Nov/2025
# 490       LARISSA ARAUJO MOURA DE RODRIGUES  2025-12              0  Dec/2025
# 491       LARISSA ARAUJO MOURA DE RODRIGUES  2026-01              0  Jan/2026
# 492       LARISSA BEZERRA MENDES DE SANTANA  2025-08              0  Aug/2025
# 493       LARISSA BEZERRA MENDES DE SANTANA  2025-09              0  Sep/2025
# 494       LARISSA BEZERRA MENDES DE SANTANA  2025-10              0  Oct/2025
# 495       LARISSA BEZERRA MENDES DE SANTANA  2025-11              0  Nov/2025
# 496       LARISSA BEZERRA MENDES DE SANTANA  2025-12              0  Dec/2025
# 497       LARISSA BEZERRA MENDES DE SANTANA  2026-01              0  Jan/2026
# 498          LARISSA DANTAS ARAUJO DE ROCHA  2025-08              0  Aug/2025
# 499          LARISSA DANTAS ARAUJO DE ROCHA  2025-09              0  Sep/2025
# 500          LARISSA DANTAS ARAUJO DE ROCHA  2025-10              0  Oct/2025
# 501          LARISSA DANTAS ARAUJO DE ROCHA  2025-11              0  Nov/2025
# 502          LARISSA DANTAS ARAUJO DE ROCHA  2025-12              0  Dec/2025
# 503          LARISSA DANTAS ARAUJO DE ROCHA  2026-01              0  Jan/2026
# 504          LARISSA MORAES MELO DE ALMEIDA  2025-08              0  Aug/2025
# 505          LARISSA MORAES MELO DE ALMEIDA  2025-09              0  Sep/2025
# 506          LARISSA MORAES MELO DE ALMEIDA  2025-10              0  Oct/2025
# 507          LARISSA MORAES MELO DE ALMEIDA  2025-11              0  Nov/2025
# 508          LARISSA MORAES MELO DE ALMEIDA  2025-12              0  Dec/2025
# 509          LARISSA MORAES MELO DE ALMEIDA  2026-01              0  Jan/2026
# 510         LARISSA SOUZA BARBOSA DE VIEIRA  2025-08              0  Aug/2025
# 511         LARISSA SOUZA BARBOSA DE VIEIRA  2025-09              0  Sep/2025
# 512         LARISSA SOUZA BARBOSA DE VIEIRA  2025-10              0  Oct/2025
# 513         LARISSA SOUZA BARBOSA DE VIEIRA  2025-11              0  Nov/2025
# 514         LARISSA SOUZA BARBOSA DE VIEIRA  2025-12              0  Dec/2025
# 515         LARISSA SOUZA BARBOSA DE VIEIRA  2026-01              0  Jan/2026
# 516           LETICIA DIAS TEIXEIRA DE LIMA  2025-08              0  Aug/2025
# 517           LETICIA DIAS TEIXEIRA DE LIMA  2025-09              0  Sep/2025
# 518           LETICIA DIAS TEIXEIRA DE LIMA  2025-10              0  Oct/2025
# 519           LETICIA DIAS TEIXEIRA DE LIMA  2025-11              0  Nov/2025
# 520           LETICIA DIAS TEIXEIRA DE LIMA  2025-12              0  Dec/2025
# 521           LETICIA DIAS TEIXEIRA DE LIMA  2026-01              0  Jan/2026
# 522     LETICIA NOGUEIRA BATISTA DE SANTANA  2025-08              0  Aug/2025
# 523     LETICIA NOGUEIRA BATISTA DE SANTANA  2025-09              0  Sep/2025
# 524     LETICIA NOGUEIRA BATISTA DE SANTANA  2025-10              0  Oct/2025
# 525     LETICIA NOGUEIRA BATISTA DE SANTANA  2025-11              0  Nov/2025
# 526     LETICIA NOGUEIRA BATISTA DE SANTANA  2025-12              0  Dec/2025
# 527     LETICIA NOGUEIRA BATISTA DE SANTANA  2026-01              0  Jan/2026
# 528        LETICIA OLIVEIRA AMARAL DE SOUZA  2025-08              1  Aug/2025
# 529        LETICIA OLIVEIRA AMARAL DE SOUZA  2025-09              0  Sep/2025
# 530        LETICIA OLIVEIRA AMARAL DE SOUZA  2025-10              0  Oct/2025
# 531        LETICIA OLIVEIRA AMARAL DE SOUZA  2025-11              1  Nov/2025
# 532        LETICIA OLIVEIRA AMARAL DE SOUZA  2025-12              0  Dec/2025
# 533        LETICIA OLIVEIRA AMARAL DE SOUZA  2026-01              0  Jan/2026
# 534        LETICIA RODRIGUES AMARAL DE LIMA  2025-08              0  Aug/2025
# 535        LETICIA RODRIGUES AMARAL DE LIMA  2025-09              1  Sep/2025
# 536        LETICIA RODRIGUES AMARAL DE LIMA  2025-10              0  Oct/2025
# 537        LETICIA RODRIGUES AMARAL DE LIMA  2025-11              0  Nov/2025
# 538        LETICIA RODRIGUES AMARAL DE LIMA  2025-12              1  Dec/2025
# 539        LETICIA RODRIGUES AMARAL DE LIMA  2026-01              0  Jan/2026
# 540          LETICIA SANTOS MORAES DA COSTA  2025-08              0  Aug/2025
# 541          LETICIA SANTOS MORAES DA COSTA  2025-09              0  Sep/2025
# 542          LETICIA SANTOS MORAES DA COSTA  2025-10              0  Oct/2025
# 543          LETICIA SANTOS MORAES DA COSTA  2025-11              0  Nov/2025
# 544          LETICIA SANTOS MORAES DA COSTA  2025-12              0  Dec/2025
# 545          LETICIA SANTOS MORAES DA COSTA  2026-01              0  Jan/2026
# 546         LUANA CUNHA MENDES DE RODRIGUES  2025-08              0  Aug/2025
# 547         LUANA CUNHA MENDES DE RODRIGUES  2025-09              0  Sep/2025
# 548         LUANA CUNHA MENDES DE RODRIGUES  2025-10              0  Oct/2025
# 549         LUANA CUNHA MENDES DE RODRIGUES  2025-11              0  Nov/2025
# 550         LUANA CUNHA MENDES DE RODRIGUES  2025-12              0  Dec/2025
# 551         LUANA CUNHA MENDES DE RODRIGUES  2026-01              0  Jan/2026
# 552          LUANA SOUZA BARBOSA DOS SANTOS  2025-08              0  Aug/2025
# 553          LUANA SOUZA BARBOSA DOS SANTOS  2025-09              0  Sep/2025
# 554          LUANA SOUZA BARBOSA DOS SANTOS  2025-10              0  Oct/2025
# 555          LUANA SOUZA BARBOSA DOS SANTOS  2025-11              0  Nov/2025
# 556          LUANA SOUZA BARBOSA DOS SANTOS  2025-12              0  Dec/2025
# 557          LUANA SOUZA BARBOSA DOS SANTOS  2026-01              0  Jan/2026
# 558       MARCELA PINTO CARVALHO DE SANTANA  2025-08              1  Aug/2025
# 559       MARCELA PINTO CARVALHO DE SANTANA  2025-09              0  Sep/2025
# 560       MARCELA PINTO CARVALHO DE SANTANA  2025-10              0  Oct/2025
# 561       MARCELA PINTO CARVALHO DE SANTANA  2025-11              1  Nov/2025
# 562       MARCELA PINTO CARVALHO DE SANTANA  2025-12              0  Dec/2025
# 563       MARCELA PINTO CARVALHO DE SANTANA  2026-01              1  Jan/2026
# 564      MARIANA CARVALHO MORAES DOS SANTOS  2025-08              0  Aug/2025
# 565      MARIANA CARVALHO MORAES DOS SANTOS  2025-09              0  Sep/2025
# 566      MARIANA CARVALHO MORAES DOS SANTOS  2025-10              0  Oct/2025
# 567      MARIANA CARVALHO MORAES DOS SANTOS  2025-11              0  Nov/2025
# 568      MARIANA CARVALHO MORAES DOS SANTOS  2025-12              0  Dec/2025
# 569      MARIANA CARVALHO MORAES DOS SANTOS  2026-01              0  Jan/2026
# 570          MARIANA DIAS BATISTA DE ARAUJO  2025-08              0  Aug/2025
# 571          MARIANA DIAS BATISTA DE ARAUJO  2025-09              0  Sep/2025
# 572          MARIANA DIAS BATISTA DE ARAUJO  2025-10              0  Oct/2025
# 573          MARIANA DIAS BATISTA DE ARAUJO  2025-11              0  Nov/2025
# 574          MARIANA DIAS BATISTA DE ARAUJO  2025-12              0  Dec/2025
# 575          MARIANA DIAS BATISTA DE ARAUJO  2026-01              0  Jan/2026
# 576        MARIANA LOPES CUNHA DE RODRIGUES  2025-08              0  Aug/2025
# 577        MARIANA LOPES CUNHA DE RODRIGUES  2025-09              0  Sep/2025
# 578        MARIANA LOPES CUNHA DE RODRIGUES  2025-10              0  Oct/2025
# 579        MARIANA LOPES CUNHA DE RODRIGUES  2025-11              0  Nov/2025
# 580        MARIANA LOPES CUNHA DE RODRIGUES  2025-12              0  Dec/2025
# 581        MARIANA LOPES CUNHA DE RODRIGUES  2026-01              0  Jan/2026
# 582         MARIANA NOGUEIRA SILVA DE ROCHA  2025-08              0  Aug/2025
# 583         MARIANA NOGUEIRA SILVA DE ROCHA  2025-09              0  Sep/2025
# 584         MARIANA NOGUEIRA SILVA DE ROCHA  2025-10              0  Oct/2025
# 585         MARIANA NOGUEIRA SILVA DE ROCHA  2025-11              0  Nov/2025
# 586         MARIANA NOGUEIRA SILVA DE ROCHA  2025-12              0  Dec/2025
# 587         MARIANA NOGUEIRA SILVA DE ROCHA  2026-01              0  Jan/2026
# 588        MARIANA ROCHA ARAUJO DE FERREIRA  2025-08              0  Aug/2025
# 589        MARIANA ROCHA ARAUJO DE FERREIRA  2025-09              0  Sep/2025
# 590        MARIANA ROCHA ARAUJO DE FERREIRA  2025-10              0  Oct/2025
# ...
# 476              23               0.00
# 477              19               0.00
# 478              22               0.00
# 479              21               0.00
# 480              21               0.00
# 481              22               0.00
# 482              23               0.00
# 483              19               0.00
# 484              22               0.00
# 485              21               0.00
# 486              21               0.00
# 487              22               0.00
# 488              23               0.00
# 489              19               0.00
# 490              22               0.00
# 491              21               0.00
# 492              21               0.00
# 493              22               0.00
# 494              23               0.00
# 495              19               0.00
# 496              22               0.00
# 497              21               0.00
# 498              21               0.00
# 499              22               0.00
# 500              23               0.00
# 501              19               0.00
# 502              22               0.00
# 503              21               0.00
# 504              21               0.00
# 505              22               0.00
# 506              23               0.00
# 507              19               0.00
# 508              22               0.00
# 509              21               0.00
# 510              21               0.00
# 511              22               0.00
# 512              23               0.00
# 513              19               0.00
# 514              22               0.00
# 515              21               0.00
# 516              21               0.00
# 517              22               0.00
# 518              23               0.00
# 519              19               0.00
# 520              22               0.00
# 521              21               0.00
# 522              21               0.00
# 523              22               0.00
# 524              23               0.00
# 525              19               0.00
# 526              22               0.00
# 527              21               0.00
# 528              21               4.76
# 529              22               0.00
# 530              23               0.00
# 531              19               5.26
# 532              22               0.00
# 533              21               0.00
# 534              21               0.00
# 535              22               4.55
# 536              23               0.00
# 537              19               0.00
# 538              22               4.55
# 539              21               0.00
# 540              21               0.00
# 541              22               0.00
# 542              23               0.00
# 543              19               0.00
# 544              22               0.00
# 545              21               0.00
# 546              21               0.00
# 547              22               0.00
# 548              23               0.00
# 549              19               0.00
# 550              22               0.00
# 551              21               0.00
# 552              21               0.00
# 553              22               0.00
# 554              23               0.00
# 555              19               0.00
# 556              22               0.00
# 557              21               0.00
# 558              21               4.76
# 559              22               0.00
# 560              23               0.00
# 561              19               5.26
# 562              22               0.00
# 563              21               4.76
# 564              21               0.00
# 565              22               0.00
# 566              23               0.00
# 567              19               0.00
# 568              22               0.00
# 569              21               0.00
# 570              21               0.00
# 571              22               0.00
# 572              23               0.00
# 573              19               0.00
# 574              22               0.00
# 575              21               0.00
# 576              21               0.00
# 577              22               0.00
# 578              23               0.00
# 579              19               0.00
# 580              22               0.00
# 581              21               0.00
# 582              21               0.00
# 583              22               0.00
# 584              23               0.00
# 585              19               0.00
# 586              22               0.00
# 587              21               0.00
# 588              21               0.00
# 589              22               0.00
# 590              23               0.00
# 591              19               0.00
# 592              22               0.00
# 593              21               0.00
# 594              21               0.00
# 595              22               0.00
# 596              23               0.00
# 597              19               0.00
# 598              22               0.00
# 599              21               0.00
# 600              21               0.00
# 601              22               0.00
# 602              23               0.00
# 603              19               0.00
# 604              22               0.00
# 605              21               0.00
# 606              21               0.00
# 607              22               0.00
# 608              23               0.00
# 609              19               0.00
# 610              22               0.00
# 611              21               0.00
# 612              21               0.00
# 613              22               0.00
# 614              23               0.00
# 615              19               0.00
# 616              22               0.00
# 617              21               0.00
# 618              21               0.00
# 619              22               0.00
# 620              23               0.00
# 621              19               0.00
# 622              22               0.00
# 623              21               0.00
# 624              21               0.00
# 625              22               0.00
# 626              23               0.00
# 627              19               0.00
# 628              22               0.00
# 629              21               0.00
# 630              21               0.00
# 631              22               0.00
# 632              23               0.00
# 633              19               0.00
# 634              22               0.00
# 635              21               0.00
# 636              21               0.00
# 637              22               0.00
# 638              23               0.00
# 639              19               0.00
# 640              22               0.00
# 641              21               0.00
# 642              21               0.00
# 643              22               0.00
# 644              23               0.00
# 645              19               0.00
# 646              22               0.00
# 647              21               0.00
# 648              21               0.00
# 649              22               0.00
# 650              23               0.00
# 651              19               0.00
# 652              22               0.00
# 653              21               0.00
# 654              21               0.00
# 655              22               0.00
# 656              23               0.00
# 657              19               0.00
# 658              22               0.00
# 659              21               0.00
# 660              21               0.00
# 661              22               0.00
# 662              23               0.00
# 663              19               0.00
# 664              22               0.00
# 665              21               0.00
# 666              21               0.00
# 667              22               9.09
# 668              23               4.35
# 669              19               5.26
# 670              22               0.00
# 671              21               0.00
# 672              21               0.00
# 673              22               0.00
# 674              23               0.00
# 675              19               0.00
# 676              22               0.00
# 677              21               0.00
# 678              21               0.00
# 679              22               0.00
# 680              23               8.70
# 681              19              10.53
# 682              22               4.55
# 683              21               0.00
# 684              21               0.00
# 685              22               0.00
# 686              23               0.00
# 687              19               0.00
# 688              22               0.00
# 689              21               0.00
# 690              21               0.00
# 691              22               4.55
# 692              23               0.00
# 693              19               0.00
# 694              22               0.00
# 695              21               4.76
# 696              21               0.00
# 697              22               4.55
# 698              23               0.00
# 699              19               5.26
# 700              22               0.00
# 701              21               0.00
# 702              21               0.00
# 703              22               0.00
# 704              23               0.00
# 705              19               0.00
# 706              22               0.00
# 707              21               0.00
# 708              21               4.76
# 709              22               0.00
# 710              23               4.35
# 711              19               0.00
# 712              22               0.00
# 713              21               9.52
# 714              21               4.76
# 715              22               0.00
# 716              23               0.00
# 717              19               0.00
# 718              22               4.55
# 719              21               0.00
# 720              21               0.00
# 721              22               0.00
# 722              23               0.00
# 723              19               0.00
# 724              22               0.00
# 725              21               0.00
# 726              21               0.00
# 727              22               0.00
# 728              23               0.00
# 729              19               0.00
# 730              22               0.00
# 731              21               0.00
# 732              21               0.00
# 733              22               0.00
# 734              23               0.00
# 735              19               0.00
# 736              22               0.00
# 737              21               0.00
# 738              21               0.00
# 739              22               0.00
# 740              23               0.00
# 741              19               0.00
# 742              22               0.00
# 743              21               0.00
# 744              21               0.00
# 745              22               0.00
# 746              23               0.00
# 747              19               0.00
# 748              22               0.00
# 749              21               0.00
# 750              21               0.00
# 751              22               0.00
# 752              23               0.00
# 753              19               0.00
# 754              22               0.00
# 755              21               0.00
# 756              21               0.00
# 757              22               0.00
# 758              23               0.00
# 759              19               0.00
# 760              22               0.00
# 761              21               0.00
# 762              21               0.00
# 763              22               0.00
# 764              23               0.00
# 765              19               0.00
# 766              22               0.00
# 767              21               0.00
# 768              21               0.00
# 769              22               0.00
# 770              23               0.00
# 771              19               0.00
# 772              22               0.00
# 773              21               0.00
# 774              21               9.52
# 775              22               0.00
# 776              23               0.00
# 777              19              10.53
# 778              22               0.00
# 779              21               0.00
# 780              21               0.00
# 781              22               0.00
# 782              23               0.00
# 783              19               0.00
# 784              22               0.00
# 785              21               0.00
# 786              21               0.00
# 787              22               4.55
# 788              23               0.00
# 789              19              15.79
# 790              22               4.55
# 791              21               0.00
# 792              21               0.00
# 793              22               0.00
# 794              23               0.00
# 795              19               0.00
# 796              22               0.00
# 797              21               0.00
# 798              21               0.00
# 799              22               0.00
# 800              23               0.00
# 801              19               0.00
# 802              22               0.00
# 803              21               0.00
# 804              21               0.00
# 805              22               0.00
# 806              23               0.00
# 807              19               0.00
# 808              22               0.00
# 809              21               0.00
# 810              21               0.00
# 811              22               0.00
# 812              23               0.00
# 813              19               0.00
# 814              22               0.00
# 815              21               0.00
# 816              21               4.76
# 817              22               9.09
# 818              23               0.00
# 819              19               5.26
# 820              22               4.55
# 821              21               0.00
# 822              21               0.00
# 823              22               0.00
# 824              23               0.00
# 825              19               0.00
# 826              22               0.00
# 827              21               0.00
# 828              21               0.00
# 829              22               0.00
# 830              23               0.00
# 831              19               0.00
# 832              22               0.00
# 833              21               0.00
# 834              21               0.00
# 835              22               0.00
# 836              23               0.00
# 837              19               0.00
# 838              22               0.00
# 839              21               0.00
# 840              21               0.00
# 841              22               0.00
# 842              23               0.00
# 843              19               0.00
# 844              22               0.00
# 845              21               0.00
#        MES MES_LABEL  DIAS_UTEIS_MES  HEADCOUNT_MES  PRESENCAS_TOTAIS  \
# 0  2025-08  Aug/2025            21.0            141            2961.0
# 1  2025-09  Sep/2025            22.0            141            3102.0
# 2  2025-10  Oct/2025            23.0            141            3243.0
# 3  2025-11  Nov/2025            19.0            141            2679.0
# 4  2025-12  Dec/2025            22.0            141            3102.0
# 5  2026-01  Jan/2026            21.0            141            2961.0
#
#    DIAS_AUSENTES_TOTAL  ABSENTEISMO_GERAL_%
# 0                 23.0                 0.78
# 1                 29.0                 0.93
# 2                 22.0                 0.68
# 3                 27.0                 1.01
# 4                 16.0                 0.52
# 5                 21.0                 0.71

# %% [markdown]
# ## Absenteismo por Semana
#
# Nesta etapa, organizamos os dados montando uma tabela que traz a quantidade de dias uteis, e de ausencias e absenteismo medio

# %% [markdown]
# ### Organizando a Ordem dos Dias da Semana

# %%
map_pt = {
    0: "Segunda-feira", 1: "Terça-feira", 2: "Quarta-feira",
    3: "Quinta-feira",  4: "Sexta-feira"
}
ordem_dias = ["Segunda-feira","Terça-feira","Quarta-feira","Quinta-feira","Sexta-feira"]

# cria DataFrame a partir do DatetimeIndex
periodo_dia_semana = pd.DataFrame({"DATA": pd.DatetimeIndex(dias_sem_feriado)})

# garante dtype datetime64[ns]
periodo_dia_semana["DATA"] = pd.to_datetime(periodo_dia_semana["DATA"], errors="coerce")

periodo_dia_semana["DIA_SEMANA"] = periodo_dia_semana["DATA"].dt.dayofweek.map(map_pt)

ocorrencias = (
    periodo_dia_semana["DIA_SEMANA"]
    .value_counts()
    .reindex(ordem_dias, fill_value=0)
)

# mapeia o dia da semana dos seus eventos com o MESMO dicionário
df_periodo["DATAS"] = pd.to_datetime(df_periodo["DATAS"], errors="coerce")
df_periodo["DIA_SEMANA"] = df_periodo["DATAS"].dt.dayofweek.map(map_pt)

aus_por_dia = (
    df_periodo.groupby("DIA_SEMANA").size()
    .reindex(ordem_dias, fill_value=0)
)

tabela_dia_semana = pd.DataFrame({
    "DIA_SEMANA": ordem_dias,
    "AUSENCIAS": aus_por_dia.values.astype(int),
    "DIAS_NO_PERIODO": ocorrencias.values.astype(int)
})

# %% [markdown]
# ### Realizando o Calculo de Absenteismo
#
# calculo = ausencias / presenças_empreegados_dias_semana

# %%
headcount_constante = total_funcionarios 

tabela_dia_semana["HEADCOUNT"] = headcount_constante
tabela_dia_semana["PRESENCAS"] = (
    tabela_dia_semana["DIAS_NO_PERIODO"] * tabela_dia_semana["HEADCOUNT"]
)

total_aus = tabela_dia_semana["AUSENCIAS"].sum()

tabela_dia_semana["%_DAS_AUSENCIAS"] = (
    tabela_dia_semana["AUSENCIAS"] / total_aus * 100
).round(2)

tabela_dia_semana["ABSENTEISMO_%"] = (
    tabela_dia_semana["AUSENCIAS"] / tabela_dia_semana["PRESENCAS"] * 100
).round(2)

tabela_dia_semana
# Out:
#       DIA_SEMANA  AUSENCIAS  DIAS_NO_PERIODO  HEADCOUNT  PRESENCAS  \
# 0  Segunda-feira         23               26        141       3666
# 1    Terça-feira         20               26        141       3666
# 2   Quarta-feira         33               26        141       3666
# 3   Quinta-feira         30               23        141       3243
# 4    Sexta-feira         32               27        141       3807
#
#    %_DAS_AUSENCIAS  ABSENTEISMO_%
# 0            16.67           0.63
# 1            14.49           0.55
# 2            23.91           0.90
# 3            21.74           0.93
# 4            23.19           0.84

# %% [markdown]
# ## Absenteismo por Missão
#
# Nesta etapa, organizamos os dados montando uma tabela que traz quantidade de fucionarios que teve ausencia por missão, dias ausentes de todos os funcionarios, os dias previstos de todos os funcionarios e o absenteismo medio de cada missão

# %% [markdown]
# ### Criando uma Tabela de Fucionários por Missão

# %%
# quantos funcionários únicos existem em cada missão
func_por_missao = (
    df.groupby("MISSAO")["NOMES"]
    .nunique()
    .rename("EMPREGADOS")
    .reset_index()
)

# %% [markdown]
# ### Tabela de Dias Ausentes por Missão

# %%
dias_ausentes_missao = (
    df_periodo.groupby("MISSAO")
    .size()
    .rename("AUSENCIAS")
    .reset_index()
)

# %% [markdown]
# ### Realizando o Calculo de Absenteismo
#
# Calculo = ausencias_por_missão / (periodos_por_missao * empregados_por_missão)
#
# O resultado final tem a quantidade de fucionarios que teve ausencia por missão, dias ausentes de todos os funcionarios, os dias previstos de todos os funcionarios
# e o absenteismo medio de cada missão

# %%
resultado_missao = (
    func_por_missao.merge(dias_ausentes_missao, on="MISSAO", how="left")
)

# missões sem ausências ficam como NaN, então vira 0
resultado_missao["AUSENCIAS"] = resultado_missao["AUSENCIAS"].fillna(0).astype(int)

# dias previstos por missão = funcionários da missão * dias úteis do período
resultado_missao["DIAS_PREVISTOS_POR_MISSAO"] = resultado_missao["EMPREGADOS"] * dias_previstos

# absenteísmo %
resultado_missao["ABSENTEISMO_%"] = (
    (resultado_missao["AUSENCIAS"] / resultado_missao["DIAS_PREVISTOS_POR_MISSAO"]) * 100
).round(2)

# ordenar do maior para o menor
resultado_missao = resultado_missao.sort_values("ABSENTEISMO_%", ascending=False)

resultado_missao
# Out:
#                             MISSAO  EMPREGADOS  AUSENCIAS  \
# 6                    Contabilidade           5         12
# 15                     OperaÃ§Ãµes           4          9
# 12               GestÃ£o de Riscos           3          6
# 8   Desenvolvimento Organizacional           6         12
# 5        ComunicaÃ§Ã£o Corporativa           5          9
# 11                      Financeiro          10         15
# 3            Business Intelligence           4          6
# 17                       Qualidade           7         10
# 9              Engenharia de Dados           6          8
# 16      Planejamento e EstratÃ©gia           7          9
# 7                    Controladoria           6          5
# 13                       JurÃ­dico           7          5
# 21      Tecnologia da InformaÃ§Ã£o           7          5
# 14                      LogÃ­stica           6          4
# 10                      Facilities           6          4
# 1           Atendimento ao Cliente          13          7
# 4            Compras e Suprimentos          12          5
# 18                Recursos Humanos          10          4
# 20      SeguranÃ§a da InformaÃ§Ã£o           8          3
# 2                Auditoria Interna           1          0
# 19       RelaÃ§Ãµes Institucionais           3          0
# 0                  AdministraÃ§Ã£o           5          0
#
#     DIAS_PREVISTOS_POR_MISSAO  ABSENTEISMO_%
# 6                         640           1.88
# 15                        512           1.76
# 12                        384           1.56
# 8                         768           1.56
# 5                         640           1.41
# 11                       1280           1.17
# 3                         512           1.17
# 17                        896           1.12
# 9                         768           1.04
# 16                        896           1.00
# 7                         768           0.65
# 13                        896           0.56
# 21                        896           0.56
# 14                        768           0.52
# 10                        768           0.52
# 1                        1664           0.42
# 4                        1536           0.33
# 18                       1280           0.31
# 20                       1024           0.29
# 2                         128           0.00
# 19                        384           0.00
# 0                         640           0.00

# %% [markdown]
# ## Gráficos ###
#
# Aqui estão os Principais Gráficos da Entrega

# %% [markdown]
# ### Grafico Geral (Top 10)
#
# Grafico com absenteismo por fucionario e os dias de ausencia (top 10) do periodo de 01-10-2025 a 21-01-2026

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patheffects as pe

TOP_N = 10


# Formatação correta de datas (Timestamp/Datetime -> str)
data_inicio_formatada = pd.to_datetime(inicio_dt).strftime('%d-%m-%Y')
data_fim_formatada    = pd.to_datetime(fim_dt).strftime('%d-%m-%Y')

# ----------------- Sanitização do DataFrame base -----------------
# Garante que a coluna de percentual exista e seja numérica
if "ABSENTEISMO_%" not in resultado_dados_geral.columns:
    raise KeyError("Coluna 'ABSENTEISMO_%' não encontrada em 'resultado_dados_geral'.")

resultado_dados_geral = resultado_dados_geral.copy()
resultado_dados_geral["ABSENTEISMO_%"] = pd.to_numeric(resultado_dados_geral["ABSENTEISMO_%"], errors="coerce").fillna(0.0)

# Detecta a coluna com dias ausentes de forma tolerante
possiveis_col_dias = ["DIAS_AUSENTES", "AUSENCIAS", "DIAS_FALTAS", "DIAS_PERDIDOS"]
col_dias = next((c for c in possiveis_col_dias if c in resultado_dados_geral.columns), None)

if col_dias is None:
    resultado_dados_geral["DIAS_AUSENTES"] = 0
    col_dias = "DIAS_AUSENTES"

# Seleciona Top N
top = (resultado_dados_geral
       .sort_values("ABSENTEISMO_%", ascending=False)
       .head(TOP_N)
       .copy())

# Mediana geral (segura contra NaN)
mediana = float(np.nanmedian(top["ABSENTEISMO_%"])) if len(top) > 0 else 0.0

# ---------- Labels do eixo Y ----------
if "NOMES" in top.columns:
    y_labels = top["NOMES"].astype(str)
else:
    # se não existir 'NOMES', usamos o index como rótulo
    y_labels = top.index.astype(str)

# Encurtar nomes longos
max_chars = 35
if hasattr(y_labels, "apply"):
    y_labels = y_labels.apply(lambda x: x if len(x) <= max_chars else x[:max_chars-3] + "...")
else:
    y_labels = y_labels.map(lambda x: x if len(x) <= max_chars else x[:max_chars-3] + "...")

# ---------- Figura ----------
fig_h = max(6, min(TOP_N, len(top)) * 0.6 + 1)  # altura mínima e ajustada ao N real
fig, ax = plt.subplots(figsize=(12, fig_h), constrained_layout=True)

bars = ax.barh(y_labels, top["ABSENTEISMO_%"], color="#1f77b4", zorder=2)
ax.invert_yaxis()

ax.set_title(f"Top {min(TOP_N, len(top))} - Maior Absenteísmo (%) | {data_inicio_formatada} a {data_fim_formatada}")
ax.set_xlabel("Absenteísmo (%)")
ax.set_ylabel("Funcionário" if "NOMES" in top.columns else "Grupo")

# Limites do eixo X com folga real (inclui mediana também)
max_val = float(top["ABSENTEISMO_%"].max()) if len(top) > 0 else 0.0
x_max = (max(max_val, mediana) * 1.30) if (max_val > 0 or mediana > 0) else 1.0
ax.set_xlim(0, x_max)

# ---------- Linha da mediana ----------
if np.isfinite(mediana):
    ax.axvline(
        mediana,
        color="crimson",
        linestyle="--",
        linewidth=2.5,
        zorder=3,
        label=f"Mediana (geral): {mediana:.2f}%"
    )

    # texto da mediana no topo (com contorno branco)
    txt_med = ax.text(
        mediana, 0.98, f"{mediana:.2f}%",
        transform=ax.get_xaxis_transform(),
        color="crimson", ha="center", va="top", fontsize=10,
        zorder=4, clip_on=True
    )
    txt_med.set_path_effects([pe.withStroke(linewidth=3, foreground="white", alpha=0.95)])

# ---------- Rótulos: % + dias ausentes ----------
# Ajustes de posicionamento
limiar = x_max * 0.10          # barra pequena
margem_interna = x_max * 0.015
margem_externa = x_max * 0.010

for bar, dias in zip(bars, top[col_dias].fillna(0).values):
    v = float(bar.get_width())
    y = bar.get_y() + bar.get_height()/2

    # texto completo que você quer exibir
    # se dias for float, convertemos para int com segurança
    try:
        dias_int = int(round(float(dias)))
    except Exception:
        dias_int = 0

    label = f"{v:.2f}% ({dias_int} dias)"

    if v >= limiar:
        # dentro da barra (branco) + contorno
        txt = ax.text(
            v - margem_interna, y, label,
            va="center", ha="right",
            color="white", fontsize=10,
            zorder=4, clip_on=True
        )
        txt.set_path_effects([pe.withStroke(linewidth=2.5, foreground="black", alpha=0.6)])
    else:
        # fora da barra com caixinha branca
        ax.text(
            v + margem_externa, y, label,
            va="center", ha="left",
            color="black", fontsize=10,
            zorder=4, clip_on=True,
            bbox=dict(boxstyle="round,pad=0.2", facecolor="white", edgecolor="none", alpha=0.95)
        )

ax.grid(axis="x", alpha=0.25, zorder=0)
ax.legend(loc="lower right", frameon=True)

plt.show()

# %% [markdown]
# ### Gráfico Mês
# Grafico com absenteismo durantes os meses do periodo de 01-10-2025 a 21-01-2026

# %%
# --- 1) Garantir que temos os dados necessários ---
# premissas: resumo_geral_mensal tem as colunas: MES (Period[M]), MES_LABEL (str), ABSENTEISMO_GERAL_% (float)
graf_geral = resumo_geral_mensal.copy()

# ordena cronologicamente
graf_geral = graf_geral.sort_values("MES").reset_index(drop=True)

# --- 2) Preparar vetores do gráfico ---
mes_labels = graf_geral["MES_LABEL"].astype(str).tolist()
y = graf_geral["ABSENTEISMO_GERAL_%"].astype(float).to_numpy()
x = np.arange(len(mes_labels))
mediana = float(np.nanmedian(y)) if len(y) else 0.0

# (opcional) título com período, se tiver inicio_dt/fim_dt:
try:
    data_inicio_formatada = pd.to_datetime(inicio_dt).strftime("%d-%m-%Y")
    data_fim_formatada    = pd.to_datetime(fim_dt).strftime("%d-%m-%Y")
    titulo_periodo = f" | {data_inicio_formatada} a {data_fim_formatada}"
except Exception:
    titulo_periodo = ""

# --- 3) Plot ---
fig, ax = plt.subplots(figsize=(11, 5), constrained_layout=True)

ax.plot(x, y, marker="o", linewidth=2, color="#1f77b4")

# linha da mediana
ax.axhline(
    mediana, color="crimson", linestyle="--", linewidth=2,
    label=f"Mediana: {mediana:.2f}%"
)

# títulos e eixos
ax.set_title(f"Absenteísmo Geral (%) por Mês{titulo_periodo}")
ax.set_xlabel("Mês")
ax.set_ylabel("Absenteísmo Geral (%)")

# eixo X
ax.set_xticks(x)
ax.set_xticklabels(mes_labels, rotation=45, ha="right")

# grade
ax.grid(True, linestyle="--", alpha=0.35)

# folga e rótulos nos pontos
if len(y):
    y_min, y_max = np.nanmin(y), np.nanmax(y)
    range_y = max(y_max - y_min, 1e-6)
    offset = range_y * 0.06 if y_max != y_min else 0.5

    for xi, yi in zip(x, y):
        if np.isfinite(yi):
            ax.text(
                xi, yi + offset, f"{yi:.2f}%",
                ha="center", va="bottom", fontsize=9,
                bbox=dict(boxstyle="round,pad=0.2", facecolor="white", edgecolor="none", alpha=0.85)
            )

ax.legend(loc="best")
plt.show()

# %% [markdown]
# ### Gráfico Dias da Semana
#
# Grafico com absenteismo dos dias da semana do periodo de 01-10-2025 a 21-01-2026

# %%
dias = tabela_dia_semana["DIA_SEMANA"].astype(str).tolist()
pct  = tabela_dia_semana["ABSENTEISMO_%"].astype(float).to_numpy()

x = np.arange(len(dias))

plt.style.use("seaborn-v0_8-whitegrid")
fig, ax = plt.subplots(figsize=(12, 5), constrained_layout=True)

bars = ax.bar(
    x, pct, width=0.6,
    color="#1f77b4",
    edgecolor="#174a7e",
    linewidth=0.8,
    label="% de absenteísmo"
)

ax.set_title(
    f"Absenteísmo por Dia da Semana (%) | {data_inicio_formatada} a {data_fim_formatada}",
    pad=14, fontweight="bold"
)

ax.set_xticks(x)
ax.set_xticklabels(dias, rotation=25, ha="right")

ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: f"{y:.0f}%"))

ax.grid(axis="y", linestyle="--", alpha=0.25)
ax.grid(axis="x", visible=False)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

max_pct = float(np.nanmax(pct)) if len(pct) else 1.0
top = max_pct * 1.18
ax.set_ylim(0, top if top > 0 else 1)

ax.bar_label(
    bars,
    labels=[f"{(v if np.isfinite(v) else 0):.2f}%" for v in pct],
    padding=3,
    fontsize=9,
    color="#1a1a1a"
)

ax.legend(frameon=False, loc="upper left")

plt.show()

# %% [markdown]
# ### Gráfico por Missão (Top 10)
# Grafico com absenteismo por missão (top 10) do periodo de 01-10-2025 a 21-01-2026

# %%
top_n = 10
top = (resultado_missao
       .sort_values("ABSENTEISMO_%", ascending=False)
       .head(top_n)
       .copy())

# Mediana geral
mediana_geral = float(resultado_missao["ABSENTEISMO_%"].median())

# (Opcional) encurtar/quebrar nomes muito longos
# Ajuste width=28 conforme seu layout
top["MISSAO_FMT"] = top["MISSAO"].astype(str).apply(lambda s: "\n".join(textwrap.wrap(s, width=28)))

plt.style.use("seaborn-v0_8-whitegrid")
fig, ax = plt.subplots(figsize=(12, 6), constrained_layout=True)

bars = ax.barh(top["MISSAO_FMT"], top["ABSENTEISMO_%"],
               color="#2E86AB", edgecolor="#1f5f78", linewidth=0.8)

ax.invert_yaxis()

# Linha vertical da mediana
ax.axvline(
    mediana_geral,
    color="purple",
    linestyle="--",
    linewidth=2,
    alpha=0.9,
    label=f"Mediana geral: {mediana_geral:.2f}%"
)

# Títulos e eixos
ax.set_title(
    f"Top {top_n} missões com maior absenteísmo (%) | {data_inicio_formatada} a {data_fim_formatada}",
    pad=12, fontweight="bold"
)
ax.set_xlabel("Absenteísmo (%)")
ax.set_ylabel("Missão")

# Eixo X como percent
ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: f"{x:.0f}%"))

# Grid mais suave
ax.grid(axis="x", linestyle="--", alpha=0.25)
ax.grid(axis="y", visible=False)

# Visual clean
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# --- Ajuste de limites para caber rótulos ---
vals = top["ABSENTEISMO_%"].to_numpy(dtype=float)
max_v = float(np.nanmax(vals)) if len(vals) else 1.0

# Folga no final do eixo X (ex.: 12% do máximo, mínimo de 0.5)
pad = max(0.5, max_v * 0.12)
ax.set_xlim(0, max_v + pad)

# --- Rótulos nas barras (inteligente: fora quando cabe; dentro se estiver apertado) ---
xmax = ax.get_xlim()[1]
for rect, v in zip(bars, vals):
    y = rect.get_y() + rect.get_height()/2

    # Se o valor estiver muito perto do limite, coloca o texto "dentro" da barra
    if v > xmax * 0.88:
        ax.text(v - pad*0.25, y, f"{v:.2f}%",
                va="center", ha="right", fontsize=9,
                color="white", fontweight="bold")
    else:
        ax.text(v + pad*0.05, y, f"{v:.2f}%",
                va="center", ha="left", fontsize=9,
                color="#1a1a1a")

# Legenda limpa
ax.legend(frameon=False, loc="lower right")

plt.show()
